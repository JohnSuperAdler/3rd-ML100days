# %%
##### DNN module

from keras.utils import to_categorical
from keras import backend as K
from keras.models import Model
from keras.applications import ResNet50
from keras.optimizers import Adagrad, RMSprop, Adam
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.preprocessing.image import ImageDataGenerator
# Out:
# Using TensorFlow backend.

# %%
##### Common moldule

import numpy as np
import os
import glob
import matplotlib.pyplot as plt
import time
from PIL import Image
from scipy.interpolate import RegularGridInterpolator
import pandas as pd

# %%
##### Path

train_db = 'database/combined_train_mx_240.npy'
label_db = 'database/combined_label_mx_240.npy'

flower_li = list(map(os.path.basename, glob.glob('database/image_data/train/*')))
flower_mapping = {flower_li[i]: i for i in range(5)}

print(flower_mapping)
# Out:
# {'daisy': 0, 'dandelion': 1, 'rose': 2, 'sunflower': 3, 'tulip': 4}

# %%
##### Load data

flower_data   = np.load(train_db)#.astype('uint8')
flower_target = np.load(label_db)#.astype('uint8')

x_train, x_test, y_train, y_test = train_test_split(flower_data, flower_target, test_size=0.2, random_state=9527)

# %%
##### Dimenssion check

(np.shape(x_train), np.shape(x_test), np.shape(y_train), np.shape(y_test))
# Out:
# ((2258, 240, 240, 3), (565, 240, 240, 3), (2258,), (565,))

# %%
##### Normalize / Categorize

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train = x_train / 255.
x_test = x_test / 255.
y_train = to_categorical(y_train, 5)
y_test = to_categorical(y_test, 5)

# %%
##### Parameter

image_size = (240, 240)
num_class = 5
batch_size = 20
num_epoches = 5
#freeze_layer = 2

# %%
net = ResNet50(include_top=False,
               weights='imagenet',
               input_tensor=None,
               input_shape=(image_size[0], image_size[1], 3))
# Out:
# C:\Users\Sauce\.conda\envs\megalopolis\lib\site-packages\keras_applications\resnet50.py:265: UserWarning: The output shape of `ResNet50(include_top=False)` has been changed since Keras 2.2.0.
#   warnings.warn('The output shape of `ResNet50(include_top=False)` '

# %%
x = net.output
x = Flatten()(x)
x = Dropout(0.5)(x)
output_layer = Dense(num_class, activation='softmax', name='softmax')(x)

# %%
net_final = Model(inputs=net.input, outputs=output_layer)

# %%
net_final.compile(optimizer=Adam(lr=1e-5),
                  loss='categorical_crossentropy', metrics=['accuracy'])

# %%
print(net_final.summary())
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 240, 240, 3)  0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 246, 246, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 120, 120, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 120, 120, 64) 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 120, 120, 64) 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 122, 122, 64) 0           activation_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 60, 60, 64)   0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, 60, 60, 64)   4160        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (BatchNormalizati (None, 60, 60, 64)   256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 60, 60, 64)   0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, 60, 60, 64)   36928       activation_2[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (BatchNormalizati (None, 60, 60, 64)   256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 60, 60, 64)   0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, 60, 60, 256)  16640       activation_3[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, 60, 60, 256)  16640       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (BatchNormalizati (None, 60, 60, 256)  1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (BatchNormalizatio (None, 60, 60, 256)  1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 60, 60, 256)  0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 60, 60, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, 60, 60, 64)   16448       activation_4[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (BatchNormalizati (None, 60, 60, 64)   256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 60, 60, 64)   0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, 60, 60, 64)   36928       activation_5[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (BatchNormalizati (None, 60, 60, 64)   256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 60, 60, 64)   0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, 60, 60, 256)  16640       activation_6[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (BatchNormalizati (None, 60, 60, 256)  1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 60, 60, 256)  0           bn2b_branch2c[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 60, 60, 256)  0           add_2[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, 60, 60, 64)   16448       activation_7[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (BatchNormalizati (None, 60, 60, 64)   256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 60, 60, 64)   0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, 60, 60, 64)   36928       activation_8[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (BatchNormalizati (None, 60, 60, 64)   256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 60, 60, 64)   0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, 60, 60, 256)  16640       activation_9[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (BatchNormalizati (None, 60, 60, 256)  1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 60, 60, 256)  0           bn2c_branch2c[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 60, 60, 256)  0           add_3[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, 30, 30, 128)  32896       activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (BatchNormalizati (None, 30, 30, 128)  512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 30, 30, 128)  0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, 30, 30, 128)  147584      activation_11[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (BatchNormalizati (None, 30, 30, 128)  512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 30, 30, 128)  0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, 30, 30, 512)  66048       activation_12[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, 30, 30, 512)  131584      activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (BatchNormalizati (None, 30, 30, 512)  2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (BatchNormalizatio (None, 30, 30, 512)  2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 30, 30, 512)  0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 30, 30, 512)  0           add_4[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, 30, 30, 128)  65664       activation_13[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (BatchNormalizati (None, 30, 30, 128)  512         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 30, 30, 128)  0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, 30, 30, 128)  147584      activation_14[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (BatchNormalizati (None, 30, 30, 128)  512         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 30, 30, 128)  0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, 30, 30, 512)  66048       activation_15[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (BatchNormalizati (None, 30, 30, 512)  2048        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 30, 30, 512)  0           bn3b_branch2c[0][0]
#                                                                  activation_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 30, 30, 512)  0           add_5[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, 30, 30, 128)  65664       activation_16[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (BatchNormalizati (None, 30, 30, 128)  512         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 30, 30, 128)  0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, 30, 30, 128)  147584      activation_17[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (BatchNormalizati (None, 30, 30, 128)  512         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 30, 30, 128)  0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, 30, 30, 512)  66048       activation_18[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (BatchNormalizati (None, 30, 30, 512)  2048        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 30, 30, 512)  0           bn3c_branch2c[0][0]
#                                                                  activation_16[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 30, 30, 512)  0           add_6[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, 30, 30, 128)  65664       activation_19[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (BatchNormalizati (None, 30, 30, 128)  512         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 30, 30, 128)  0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, 30, 30, 128)  147584      activation_20[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (BatchNormalizati (None, 30, 30, 128)  512         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 30, 30, 128)  0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, 30, 30, 512)  66048       activation_21[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (BatchNormalizati (None, 30, 30, 512)  2048        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 30, 30, 512)  0           bn3d_branch2c[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 30, 30, 512)  0           add_7[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, 15, 15, 256)  131328      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (BatchNormalizati (None, 15, 15, 256)  1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 15, 15, 256)  0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, 15, 15, 256)  590080      activation_23[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (BatchNormalizati (None, 15, 15, 256)  1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 15, 15, 256)  0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, 15, 15, 1024) 263168      activation_24[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, 15, 15, 1024) 525312      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (BatchNormalizati (None, 15, 15, 1024) 4096        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (BatchNormalizatio (None, 15, 15, 1024) 4096        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 15, 15, 1024) 0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 15, 15, 1024) 0           add_8[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, 15, 15, 256)  262400      activation_25[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (BatchNormalizati (None, 15, 15, 256)  1024        res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 15, 15, 256)  0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, 15, 15, 256)  590080      activation_26[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (BatchNormalizati (None, 15, 15, 256)  1024        res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 15, 15, 256)  0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, 15, 15, 1024) 263168      activation_27[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (BatchNormalizati (None, 15, 15, 1024) 4096        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 15, 15, 1024) 0           bn4b_branch2c[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 15, 15, 1024) 0           add_9[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, 15, 15, 256)  262400      activation_28[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (BatchNormalizati (None, 15, 15, 256)  1024        res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 15, 15, 256)  0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, 15, 15, 256)  590080      activation_29[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (BatchNormalizati (None, 15, 15, 256)  1024        res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 15, 15, 256)  0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, 15, 15, 1024) 263168      activation_30[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (BatchNormalizati (None, 15, 15, 1024) 4096        res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 15, 15, 1024) 0           bn4c_branch2c[0][0]
#                                                                  activation_28[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 15, 15, 1024) 0           add_10[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, 15, 15, 256)  262400      activation_31[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (BatchNormalizati (None, 15, 15, 256)  1024        res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 15, 15, 256)  0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, 15, 15, 256)  590080      activation_32[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (BatchNormalizati (None, 15, 15, 256)  1024        res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 15, 15, 256)  0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, 15, 15, 1024) 263168      activation_33[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (BatchNormalizati (None, 15, 15, 1024) 4096        res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 15, 15, 1024) 0           bn4d_branch2c[0][0]
#                                                                  activation_31[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 15, 15, 1024) 0           add_11[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, 15, 15, 256)  262400      activation_34[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (BatchNormalizati (None, 15, 15, 256)  1024        res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 15, 15, 256)  0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, 15, 15, 256)  590080      activation_35[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (BatchNormalizati (None, 15, 15, 256)  1024        res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 15, 15, 256)  0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, 15, 15, 1024) 263168      activation_36[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (BatchNormalizati (None, 15, 15, 1024) 4096        res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 15, 15, 1024) 0           bn4e_branch2c[0][0]
#                                                                  activation_34[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 15, 15, 1024) 0           add_12[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, 15, 15, 256)  262400      activation_37[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (BatchNormalizati (None, 15, 15, 256)  1024        res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 15, 15, 256)  0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, 15, 15, 256)  590080      activation_38[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (BatchNormalizati (None, 15, 15, 256)  1024        res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 15, 15, 256)  0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, 15, 15, 1024) 263168      activation_39[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (BatchNormalizati (None, 15, 15, 1024) 4096        res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 15, 15, 1024) 0           bn4f_branch2c[0][0]
#                                                                  activation_37[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 15, 15, 1024) 0           add_13[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a (Conv2D)         (None, 8, 8, 512)    524800      activation_40[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a (BatchNormalizati (None, 8, 8, 512)    2048        res5a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 8, 8, 512)    0           bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b (Conv2D)         (None, 8, 8, 512)    2359808     activation_41[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b (BatchNormalizati (None, 8, 8, 512)    2048        res5a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 8, 8, 512)    0           bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c (Conv2D)         (None, 8, 8, 2048)   1050624     activation_42[0][0]
# __________________________________________________________________________________________________
# res5a_branch1 (Conv2D)          (None, 8, 8, 2048)   2099200     activation_40[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c (BatchNormalizati (None, 8, 8, 2048)   8192        res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1 (BatchNormalizatio (None, 8, 8, 2048)   8192        res5a_branch1[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 8, 8, 2048)   0           bn5a_branch2c[0][0]
#                                                                  bn5a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 8, 8, 2048)   0           add_14[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a (Conv2D)         (None, 8, 8, 512)    1049088     activation_43[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2a (BatchNormalizati (None, 8, 8, 512)    2048        res5b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 8, 8, 512)    0           bn5b_branch2a[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b (Conv2D)         (None, 8, 8, 512)    2359808     activation_44[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2b (BatchNormalizati (None, 8, 8, 512)    2048        res5b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 8, 8, 512)    0           bn5b_branch2b[0][0]
# __________________________________________________________________________________________________
# res5b_branch2c (Conv2D)         (None, 8, 8, 2048)   1050624     activation_45[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2c (BatchNormalizati (None, 8, 8, 2048)   8192        res5b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 8, 8, 2048)   0           bn5b_branch2c[0][0]
#                                                                  activation_43[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 8, 8, 2048)   0           add_15[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a (Conv2D)         (None, 8, 8, 512)    1049088     activation_46[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2a (BatchNormalizati (None, 8, 8, 512)    2048        res5c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 8, 8, 512)    0           bn5c_branch2a[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b (Conv2D)         (None, 8, 8, 512)    2359808     activation_47[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2b (BatchNormalizati (None, 8, 8, 512)    2048        res5c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 8, 8, 512)    0           bn5c_branch2b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2c (Conv2D)         (None, 8, 8, 2048)   1050624     activation_48[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2c (BatchNormalizati (None, 8, 8, 2048)   8192        res5c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 8, 8, 2048)   0           bn5c_branch2c[0][0]
#                                                                  activation_46[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 8, 8, 2048)   0           add_16[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 131072)       0           activation_49[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 131072)       0           flatten_1[0][0]
# __________________________________________________________________________________________________
# softmax (Dense)                 (None, 5)            655365      dropout_1[0][0]
# ==================================================================================================
# Total params: 24,243,077
# Trainable params: 24,189,957
# Non-trainable params: 53,120
# __________________________________________________________________________________________________
# None

# %%
augment_generator = ImageDataGenerator(rotation_range=40,
                                       width_shift_range=0.2,
                                       height_shift_range=0.2,
                                       rescale=1./255,
                                       shear_range=0.2,
                                       zoom_range=0.2,
                                       horizontal_flip=True,
                                       fill_mode='nearest'
                                      )

# %%
history = net_final.fit_generator(augment_generator.flow(x_train, y_train, batch_size=batch_size),
                    steps_per_epoch=int(len(x_train)/batch_size), # 一個 epochs 要執行幾次 update，通常是資料量除以 batch size
                    epochs=num_epoches,
                    verbose=1,
                    validation_data=(x_test, y_test))
# Out:
# Epoch 1/5
# 112/112 [==============================] - 97s 871ms/step - loss: 2.6426 - accuracy: 0.3405 - val_loss: 1.8947 - val_accuracy: 0.2478
# Epoch 2/5
# 112/112 [==============================] - 81s 721ms/step - loss: 1.8402 - accuracy: 0.4942 - val_loss: 2.3157 - val_accuracy: 0.2584
# Epoch 3/5
# 112/112 [==============================] - 81s 726ms/step - loss: 1.4236 - accuracy: 0.6023 - val_loss: 1.6862 - val_accuracy: 0.4195
# Epoch 4/5
# 112/112 [==============================] - 81s 727ms/step - loss: 1.1934 - accuracy: 0.6679 - val_loss: 1.0642 - val_accuracy: 0.6779
# Epoch 5/5
# 112/112 [==============================] - 81s 727ms/step - loss: 1.0731 - accuracy: 0.6972 - val_loss: 0.6714 - val_accuracy: 0.7841

# %%
score = net_final.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.6714184874981906
# Test accuracy: 0.7840707898139954

# %%
net_final.save('model/STD_datagen_1230_05.h5')

# %%
##### Test on unknown sample

# %%
def resampleRGI3d(input_mx, resize_to, dtype='float32'):
    # Ref: 10 3-A-7
    # Ver. 2.1
    # input_mx : numpy array, the original target matrix
    # resize_to: list or tuple with 3 int inside
    a, b, c = np.shape(input_mx)
    p, q, r = resize_to
    z_grid = np.linspace(0, p - 1, a)
    y_grid = np.linspace(0, q - 1, b)
    x_grid = np.linspace(0, r - 1, c)
    RGI = RegularGridInterpolator((z_grid, y_grid, x_grid), input_mx)
    z_grid_t2 = np.arange(p)
    y_grid_t2 = np.arange(q)
    x_grid_t2 = np.arange(r)
    meshgrid_para = np.meshgrid(z_grid_t2, y_grid_t2, x_grid_t2)
    RGI_mesh_mx = RGI((meshgrid_para[0], meshgrid_para[1], meshgrid_para[2]))
    RGI_mx = np.transpose(RGI_mesh_mx, axes=[1, 0, 2]).astype(dtype)
    return RGI_mx

def happy_time(start,stop):
    process_time = round(stop - start)
    ss = process_time % 60
    mm = process_time // 60 % 60
    hh = process_time // 3600
    duration = "Process time == {}s == {}H {}m {}s".format(process_time,hh,mm,ss)
    return duration

# %%
path_unknown = glob.glob('database/image_data/test/*')
path_unknown[:5]
# Out:
# ['database/image_data/test\\0028624c49b3e0610ff9f1d111f5d532.jpg',
#  'database/image_data/test\\002c30700185b7971369258b438070d5.jpg',
#  'database/image_data/test\\00852f4f666acecd0c0d140365b42efd.jpg',
#  'database/image_data/test\\00c08828fce04e360c732cac01edad9e.jpg',
#  'database/image_data/test\\00d366e7877b6a78b104b57d67b60e6b.jpg']

# %%
#path_train_0 = glob.glob(os.path.join(path_train, list(flower_mapping.keys())[i], '*'))
#pic_store_dict = None
#pic_store_dict = {}

id_li = []
flower_class = []
pred_li = []
loop_start = time.time()

for j in range(len(path_unknown)):
    serial = os.path.basename(path_unknown[j])[:-4]
    temp_pic = np.asarray(Image.open(path_unknown[j]))
    temp_shape = np.shape(temp_pic)
    if temp_shape[0] > 640:
        temp_pic = temp_pic[:640]
        temp_shape = np.shape(temp_pic)
    if temp_shape[1] > 640:
        temp_pic = temp_pic[:, :640]
        temp_shape = np.shape(temp_pic)
    if temp_shape[0] > 240:
        temp_pic = resampleRGI3d(temp_pic, (240, int(temp_shape[1]*240/temp_shape[0]), 3))
        temp_shape = np.shape(temp_pic)
    if temp_shape[1] > 240:
        temp_pic = resampleRGI3d(temp_pic, (int(temp_shape[0]*240/temp_shape[1]), 240, 3))
        temp_shape = np.shape(temp_pic)
    temp_pic = np.pad(temp_pic, ((0, 240 - temp_shape[0]), (0, 240 - temp_shape[1]), (0, 0)), 'constant', constant_values=0)
    temp_pic = np.expand_dims(temp_pic, axis = 0)
    pred = net_final.predict(temp_pic)[0]
    pred_li.append(pred)
    id_li.append(serial)
    flower_class.append(list(pred).index(max(pred)))
    if (j+1) % 200 == 0:
        print(j+1, 'files done.', happy_time(loop_start, time.time()))
    #pic_store_dict[serial] = temp_pic
#stack_a = np.stack([pic_store_dict[x] for x in list(pic_store_dict.keys())], axis=0)
#total_dict[sub_folder_li[i]] = stack_a
# Out:
# 200 files done. Process time == 13s == 0H 0m 13s
# 400 files done. Process time == 28s == 0H 0m 28s
# 600 files done. Process time == 42s == 0H 0m 42s
# 800 files done. Process time == 56s == 0H 0m 56s
# 1000 files done. Process time == 71s == 0H 1m 11s
# 1200 files done. Process time == 84s == 0H 1m 24s
# 1400 files done. Process time == 97s == 0H 1m 37s
# 1600 files done. Process time == 111s == 0H 1m 51s
# 1800 files done. Process time == 124s == 0H 2m 4s
# 2000 files done. Process time == 138s == 0H 2m 18s

# %%
pred_li
# Out:
# [array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.000000e+00, 0.000000e+00, 0.000000e+00, 1.000000e+00,
#         3.364495e-11], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.000000e+00, 0.000000e+00, 0.000000e+00, 6.998077e-10,
#         1.000000e+00], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 4.5695256e-22,
#         1.0000000e+00], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 6.3424837e-31,
#         1.0000000e+00], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.0000000e+00,
#         1.0120669e-35], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.0000000e+00,
#         8.3612433e-16], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 4.5509285e-15,
#         1.0000000e+00], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.0000000e+00,
#         7.0387885e-13], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.0000000e+00,
#         5.8348783e-18], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 2.2370776e-33,
#         1.0000000e+00], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.6093261e-21,
#         1.0000000e+00], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.        , 0.        , 0.        , 0.10110722, 0.8988928 ],
#        dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([4.4804925e-30, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         1.0000000e+00], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 3.2027827e-31,
#         1.0000000e+00], dtype=float32),
#  array([0.000000e+00, 0.000000e+00, 0.000000e+00, 4.130396e-37,
#         1.000000e+00], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.2127487e-24,
#         1.0000000e+00], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0.        , 0.        , 0.        , 0.9308379 , 0.06916209],
#        dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.0000000e+00,
#         2.9983368e-28], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 5.4440454e-16,
#         1.0000000e+00], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.000000e+00, 0.000000e+00, 0.000000e+00, 1.000000e+00,
#         3.729338e-30], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.00000e+00, 0.00000e+00, 0.00000e+00, 9.25361e-15, 1.00000e+00],
#        dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.0000000e+00,
#         1.7969491e-37], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.000000e+00, 0.000000e+00, 0.000000e+00, 1.000000e+00,
#         7.289114e-14], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.000000e+00, 0.000000e+00, 0.000000e+00, 1.000000e+00,
#         2.536239e-24], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.3451926e-34,
#         1.0000000e+00], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.000000e+00, 0.000000e+00, 0.000000e+00, 9.010971e-33,
#         1.000000e+00], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.0000000e+00,
#         2.1216832e-13], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.00114229, 0.        , 0.        , 0.        , 0.99885774],
#        dtype=float32),
#  array([0.000000e+00, 0.000000e+00, 0.000000e+00, 1.000000e+00,
#         7.909814e-29], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.000000e+00, 8.507364e-26, 0.000000e+00, 1.000000e+00,
#         0.000000e+00], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.000000e+00, 0.000000e+00, 0.000000e+00, 1.831969e-32,
#         1.000000e+00], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 3.6659258e-28,
#         1.0000000e+00], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 6.9575303e-06,
#         9.9999309e-01], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 9.9994934e-01,
#         5.0618590e-05], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 3.4844425e-19,
#         1.0000000e+00], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00, 2.3898e-12],
#        dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.0000000e+00,
#         3.8135113e-38], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0.        , 0.        , 0.        , 0.00117248, 0.9988275 ],
#        dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.0000000e+00,
#         1.7615688e-36], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.000000e+00, 0.000000e+00, 0.000000e+00, 5.068405e-33,
#         1.000000e+00], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0.000000e+00, 0.000000e+00, 0.000000e+00, 2.989881e-38,
#         1.000000e+00], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 2.8137702e-33,
#         1.0000000e+00], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0.000000e+00, 0.000000e+00, 0.000000e+00, 4.356653e-27,
#         1.000000e+00], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 9.9980396e-01,
#         1.9607232e-04], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([1.1231290e-09, 0.0000000e+00, 0.0000000e+00, 3.4516834e-28,
#         1.0000000e+00], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.0000000e+00,
#         8.1709226e-38], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.000000e+00, 0.000000e+00, 0.000000e+00, 9.028289e-23,
#         1.000000e+00], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 2.3470214e-27,
#         1.0000000e+00], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.        , 0.        , 0.        , 0.00135696, 0.9986431 ],
#        dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.0000000e+00,
#         3.1546296e-10], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 4.6793676e-08,
#         1.0000000e+00], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 4.7145204e-31,
#         1.0000000e+00], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0.00000e+00, 0.00000e+00, 0.00000e+00, 1.00000e+00, 9.66117e-10],
#        dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 4.2373008e-10,
#         1.0000000e+00], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([1.5823787e-11, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         1.0000000e+00], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.2073731e-28,
#         1.0000000e+00], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([2.0420583e-16, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         1.0000000e+00], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.0000000e+00,
#         1.4351873e-27], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.0000000e+00,
#         3.1720456e-38], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.0000000e+00,
#         3.4647347e-18], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.0000000e+00,
#         1.4379554e-26], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.0000000e+00,
#         3.5623622e-15], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.        , 0.        , 0.        , 0.01025247, 0.9897475 ],
#        dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.        , 0.        , 0.        , 0.01128969, 0.98871034],
#        dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.0000000e+00,
#         1.3795846e-20], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.0000000e+00,
#         1.6726393e-18], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.0991226e-24,
#         1.0000000e+00], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0.000000e+00, 0.000000e+00, 0.000000e+00, 1.901088e-21,
#         1.000000e+00], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.9692353e-10,
#         1.0000000e+00], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.0000000e+00,
#         2.2017705e-28], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.0299963e-32,
#         1.0000000e+00], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.7670878e-21,
#         1.0000000e+00], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.0000000e+00,
#         2.1496779e-26], dtype=float32),
#  array([0.000000e+00, 0.000000e+00, 0.000000e+00, 5.689035e-30,
#         1.000000e+00], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.0000000e+00,
#         2.4865138e-10], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.0000000e+00,
#         5.5965983e-25], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([1.8297702e-11, 0.0000000e+00, 0.0000000e+00, 9.8223567e-01,
#         1.7764375e-02], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.8632615e-25,
#         1.0000000e+00], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.        , 0.        , 0.        , 0.00637659, 0.99362344],
#        dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.000000e+00, 0.000000e+00, 0.000000e+00, 1.000000e+00,
#         4.105167e-08], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.0000000e+00,
#         5.1407516e-30], dtype=float32),
#  array([0.000000e+00, 0.000000e+00, 0.000000e+00, 5.414424e-10,
#         1.000000e+00], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 9.9999988e-01,
#         1.6643344e-07], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.0000000e+00,
#         4.1447602e-14], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 2.8808454e-35,
#         1.0000000e+00], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.0000000e+00,
#         3.3137315e-14], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 9.9986315e-01,
#         1.3682339e-04], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.0000000e+00,
#         1.1407528e-20], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0.000000e+00, 0.000000e+00, 0.000000e+00, 1.000000e+00,
#         6.801227e-22], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.000000e+00, 0.000000e+00, 0.000000e+00, 9.682189e-12,
#         1.000000e+00], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 4.0473014e-26,
#         1.0000000e+00], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 4.3515924e-17,
#         1.0000000e+00], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.0000000e+00,
#         1.2420222e-20], dtype=float32),
#  array([0.        , 0.        , 0.        , 0.00278959, 0.99721044],
#        dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.0000000e+00,
#         1.1123441e-27], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0.000000e+00, 0.000000e+00, 0.000000e+00, 5.925941e-36,
#         1.000000e+00], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 7.2259646e-29,
#         1.0000000e+00], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.000000e+00, 0.000000e+00, 0.000000e+00, 1.965698e-20,
#         1.000000e+00], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.0000000e+00,
#         2.9964465e-23], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.0119993e-24,
#         1.0000000e+00], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.0000000e+00,
#         1.6568229e-15], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.0000000e+00,
#         3.5916683e-32], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.0019785e-14,
#         1.0000000e+00], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.000000e+00, 0.000000e+00, 0.000000e+00, 1.000000e+00,
#         6.603341e-10], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 4.3524602e-30,
#         1.0000000e+00], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.000000e+00, 0.000000e+00, 0.000000e+00, 1.000000e+00,
#         6.093537e-14], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.0000000e+00,
#         1.8171677e-29], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 5.0357914e-35,
#         1.0000000e+00], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([1.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         1.2847168e-29], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 3.1227025e-22,
#         1.0000000e+00], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.000000e+00, 0.000000e+00, 0.000000e+00, 9.999939e-01,
#         6.021613e-06], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.        , 0.        , 0.        , 0.19881703, 0.8011829 ],
#        dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.0000000e+00,
#         5.1773126e-32], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0.        , 0.        , 0.        , 0.5717106 , 0.42828944],
#        dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 9.9977297e-01,
#         2.2708104e-04], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.000000e+00, 0.000000e+00, 0.000000e+00, 1.000000e+00,
#         1.136039e-16], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.03300314e-04,
#         9.99896646e-01], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.0000000e+00,
#         2.2076588e-27], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.3585388e-34,
#         1.0000000e+00], dtype=float32),
#  array([0.000000e+00, 0.000000e+00, 0.000000e+00, 1.000000e+00,
#         2.687436e-09], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.0000000e+00,
#         6.1048266e-27], dtype=float32),
#  array([3.4763252e-22, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         1.0000000e+00], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([3.5066284e-06, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         9.9999654e-01], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.000000e+00, 0.000000e+00, 0.000000e+00, 6.666223e-36,
#         1.000000e+00], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.7612494e-25,
#         1.0000000e+00], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.000000e+00, 0.000000e+00, 0.000000e+00, 1.000000e+00,
#         5.913818e-35], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 5.7384317e-35,
#         1.0000000e+00], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.1062428e-26,
#         1.0000000e+00], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 3.0828554e-19,
#         1.0000000e+00], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.000000e+00, 0.000000e+00, 0.000000e+00, 8.647935e-10,
#         1.000000e+00], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 7.5215185e-09,
#         1.0000000e+00], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.0000000e+00,
#         2.5970374e-17], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.0000000e+00,
#         1.8095673e-12], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.0000000e+00,
#         4.1992053e-36], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 9.9999714e-01,
#         2.8678865e-06], dtype=float32),
#  array([0.        , 0.        , 0.        , 0.71241355, 0.28758642],
#        dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.2654668e-19,
#         1.0000000e+00], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 3.1901607e-17,
#         1.0000000e+00], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.0911014e-32,
#         1.0000000e+00], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.0038875e-29,
#         1.0000000e+00], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.000000e+00, 0.000000e+00, 0.000000e+00, 4.886662e-07,
#         9.999995e-01], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 4.3031745e-04,
#         9.9956971e-01], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([1.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         1.1022039e-25], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 2.6110777e-14,
#         1.0000000e+00], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 3.4958060e-07,
#         9.9999964e-01], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.0000000e+00,
#         5.6021897e-27], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([2.6798988e-37, 0.0000000e+00, 0.0000000e+00, 2.8484558e-35,
#         1.0000000e+00], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.000000e+00, 0.000000e+00, 0.000000e+00, 4.444714e-13,
#         1.000000e+00], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 5.9897714e-32,
#         1.0000000e+00], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.1627334e-06,
#         9.9999881e-01], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.0000000e+00,
#         2.0229288e-33], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([1.6650329e-06, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         9.9999833e-01], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([1.7148506e-22, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         1.0000000e+00], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 3.6822904e-16,
#         1.0000000e+00], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 2.9264148e-19,
#         1.0000000e+00], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.0000000e+00,
#         2.8776077e-11], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 9.9990976e-01,
#         9.0178510e-05], dtype=float32),
#  array([0.000000e+00, 0.000000e+00, 0.000000e+00, 4.219636e-11,
#         1.000000e+00], dtype=float32),
#  array([0.        , 0.        , 0.        , 0.01427294, 0.985727  ],
#        dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.000000e+00, 0.000000e+00, 0.000000e+00, 9.996259e-01,
#         3.740457e-04], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.0000000e+00,
#         4.0017415e-16], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.0000000e+00,
#         2.4730977e-23], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.0000000e+00,
#         7.1501985e-30], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([1.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         8.440168e-32], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.000000e+00, 0.000000e+00, 0.000000e+00, 5.900722e-21,
#         1.000000e+00], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.1835713e-24,
#         1.0000000e+00], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.000000e+00, 0.000000e+00, 0.000000e+00, 1.000000e+00,
#         2.337422e-15], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.0000000e+00,
#         2.7662367e-35], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.3433308e-27,
#         1.0000000e+00], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.00000e+00, 0.00000e+00, 0.00000e+00, 1.00000e+00, 5.63478e-15],
#        dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.0000000e+00,
#         1.2140416e-14], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.00000e+00, 0.00000e+00, 0.00000e+00, 1.00000e+00, 9.69356e-37],
#        dtype=float32),
#  array([0.000000e+00, 0.000000e+00, 0.000000e+00, 1.000000e+00,
#         2.511149e-33], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.0000000e+00,
#         5.6614425e-34], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0.        , 0.        , 0.        , 0.00660778, 0.99339217],
#        dtype=float32),
#  array([0.000000e+00, 0.000000e+00, 0.000000e+00, 1.000000e+00,
#         4.625622e-33], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 2.8258637e-31,
#         1.0000000e+00], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 2.2784443e-04,
#         9.9977213e-01], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.0000000e+00,
#         3.8074005e-26], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([9.9999893e-01, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         1.0846823e-06], dtype=float32),
#  array([0.        , 0.        , 0.        , 0.98414433, 0.01585571],
#        dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.0000000e+00,
#         1.2450443e-12], dtype=float32),
#  array([1., 0., 0., 0., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 2.3148827e-08,
#         1.0000000e+00], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 2.4830538e-29,
#         1.0000000e+00], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 9.9999976e-01,
#         2.0760062e-07], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.        , 0.        , 0.        , 0.7250285 , 0.27497151],
#        dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 9.9999905e-01,
#         9.0596109e-07], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.0000000e+00,
#         1.5655131e-26], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.000000e+00, 0.000000e+00, 0.000000e+00, 9.221735e-34,
#         1.000000e+00], dtype=float32),
#  array([0.000000e+00, 0.000000e+00, 0.000000e+00, 1.000000e+00,
#         4.674136e-10], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.        , 0.        , 0.        , 0.03889104, 0.961109  ],
#        dtype=float32),
#  array([0., 0., 0., 1., 0.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.0000000e+00,
#         1.8627067e-18], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 5.2632225e-07,
#         9.9999952e-01], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.3505054e-17,
#         1.0000000e+00], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 2.4961312e-14,
#         1.0000000e+00], dtype=float32),
#  array([0., 0., 0., 0., 1.], dtype=float32),
#  ...]

# %%
pred_result_df = pd.DataFrame(columns=['id', 'flower_class'])
pred_result_df['id'] = id_li
pred_result_df['flower_class'] = flower_class
pred_result_df
# Out:
#                                     id  flower_class
# 0     0028624c49b3e0610ff9f1d111f5d532             4
# 1     002c30700185b7971369258b438070d5             4
# 2     00852f4f666acecd0c0d140365b42efd             4
# 3     00c08828fce04e360c732cac01edad9e             4
# 4     00d366e7877b6a78b104b57d67b60e6b             4
# ...                                ...           ...
# 1995  ff7eac29b6d7a33fbd8009677c3e9c58             3
# 1996  ffbc32a7b67dfe72b8d35d4b1b35fd6c             4
# 1997  ffea1f275c05accb0a6bfd1203620c7e             3
# 1998  ffeb2a1cf53464b6af937ab8af0c2946             4
# 1999  ffefcc68e2e7eed8b17b0b5b0f740538             3
#
# [2000 rows x 2 columns]

# %%
pred_result_df.to_csv('model/pred_result_STD_datagen_1230_05_datagen_RESNET.csv', index=False)

# %%
#####
#####
#####
