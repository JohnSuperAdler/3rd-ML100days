# %%
##### DNN module

from keras.utils import to_categorical
from keras.models import Sequential, Model
from keras.optimizers import RMSprop, Adagrad, Adam, SGD
from keras.layers import Conv2D, Activation, MaxPooling2D, Dropout, Flatten, Dense
from keras.layers import BatchNormalization
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l1, l2, l1_l2

#from sklearn.model_selection import train_test_split
#from keras import backend as K
#from keras.applications import ResNet50
# Out:
# Using TensorFlow backend.

# %%
#import os
#os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# %%
##### Common moldule

import numpy as np
import os
import glob
import matplotlib.pyplot as plt
import time
from PIL import Image
from scipy.interpolate import RegularGridInterpolator
import pandas as pd

# %%
##### Control Panel

fn_serial   = '018'
batch_size  = 24
num_classes = 5
epochs      = 100
pic_size    = 300
pool_size   = (2, 2)

# %%
##### Selection

Conv2D_size = [(3, 3), (5, 5), (7, 7)]
drop_out    = [0., 0.1]
l2_ratio    = [1e-4, 1e-8]
optimizer   = [Adam(lr=0.01),
               Adam(lr=0.001),
               RMSprop(lr=0.01),
               RMSprop(lr=0.001),
               SGD(lr=0.01, momentum=0.95),
               SGD(lr=0.001, momentum=0.95),
              ]

total_item = len(Conv2D_size) * len(drop_out) * len(l2_ratio) * len(optimizer)
print('Total config:', total_item)
# Out:
# Total config: 72

# %%
##### Note 

#Conv2D_size = [(3, 3), (5, 5), (7, 7)]
#drop_out    = [0., 0.1]
#l2_ratio    = [1e-4, 1e-8]
#optimizer   = [Adam(lr=0.01),
#               Adam(lr=0.001),
#               RMSprop(lr=0.01),
#               RMSprop(lr=0.001),
#               SGD(lr=0.01, momentum=0.95),
#               SGD(lr=0.001, momentum=0.95),
#              ]

# Good result:
# 0013 0103 0104 0113 0114 1013 1014 1015 1104 1105 1115 2004

# %%
def create_model(model_name, Conv2D_size, pic_size, l2_ratio, pool_size, drop_out_ratio):
    model = Sequential()
    model.name=model_name
    model.add(Conv2D(32, Conv2D_size, padding='same', input_shape=(pic_size, pic_size, 3), kernel_regularizer=l2(l2_ratio)))
    model.add(Activation('relu'))
    #model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=pool_size))
    model.add(Dropout(drop_out_ratio))
    model.add(Conv2D(128, Conv2D_size, padding='same', kernel_regularizer=l2(l2_ratio)))
    model.add(Activation('relu'))
    #model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=pool_size))
    model.add(Dropout(drop_out_ratio))
    model.add(Conv2D(64, Conv2D_size, padding='same', kernel_regularizer=l2(l2_ratio)))
    model.add(Activation('relu'))
    #model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=pool_size))
    model.add(Dropout(drop_out_ratio))
    model.add(Conv2D(32, Conv2D_size, padding='same', kernel_regularizer=l2(l2_ratio)))
    model.add(Activation('relu'))
    #model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=pool_size))
    model.add(Dropout(drop_out_ratio))
    model.add(Flatten())
    model.add(Dense(512, kernel_regularizer=l2(l2_ratio)))
    model.add(Activation('relu'))
    #model.add(BatchNormalization())
    model.add(Dropout(drop_out_ratio))
    model.add(Dense(num_classes))
    model.add(Activation('softmax'))
    return model

# %%
def create_compile(optimizer):
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# %%
def resampleRGI3d(input_mx, resize_to, dtype='float32'):
    # Ref: 10 3-A-7
    # Ver. 2.1
    # input_mx : numpy array, the original target matrix
    # resize_to: list or tuple with 3 int inside
    a, b, c = np.shape(input_mx)
    p, q, r = resize_to
    z_grid = np.linspace(0, p - 1, a)
    y_grid = np.linspace(0, q - 1, b)
    x_grid = np.linspace(0, r - 1, c)
    RGI = RegularGridInterpolator((z_grid, y_grid, x_grid), input_mx)
    z_grid_t2 = np.arange(p)
    y_grid_t2 = np.arange(q)
    x_grid_t2 = np.arange(r)
    meshgrid_para = np.meshgrid(z_grid_t2, y_grid_t2, x_grid_t2)
    RGI_mesh_mx = RGI((meshgrid_para[0], meshgrid_para[1], meshgrid_para[2]))
    RGI_mx = np.transpose(RGI_mesh_mx, axes=[1, 0, 2]).astype(dtype)
    return RGI_mx

def happy_time(start,stop):
    process_time = round(stop - start)
    ss = process_time % 60
    mm = process_time // 60 % 60
    hh = process_time // 3600
    duration = "Process time == {}s == {}H {}m {}s".format(process_time,hh,mm,ss)
    return duration

# %%
path_unknown = glob.glob('database/image_data/test/*')

# %%
unknown_dict = {}

for j in range(len(path_unknown)):
    serial = os.path.basename(path_unknown[j])[:-4]
    temp_pic = np.asarray(Image.open(path_unknown[j]))
    temp_pic = resampleRGI3d(temp_pic, (pic_size, pic_size, 3))
    temp_shape = np.shape(temp_pic)
    temp_pic = np.expand_dims(temp_pic, axis = 0)
    unknown_dict[serial] = temp_pic

print('Length of dict:', len(list(unknown_dict.keys())))
# Out:
# Length of dict: 2000

# %%
##### ImageDataGenerator

augment_generator = ImageDataGenerator(
                                       rotation_range=20,
                                       rescale=1./255,
                                       #featurewise_center=True,
                                       #featurewise_std_normalization=True,
                                       width_shift_range=0.2,
                                       height_shift_range=0.2,
                                       horizontal_flip=True,
                                       #data_format='channels_last'
                                      )

# %%
##### Generator for train and validation

train_generator = augment_generator.flow_from_directory('database/image_data/sep_train',
                                                        target_size=(pic_size, pic_size),
                                                        batch_size=batch_size,
                                                        class_mode='categorical')
valid_generator = augment_generator.flow_from_directory('database/image_data/sep_valid',
                                                        target_size=(pic_size, pic_size),
                                                        batch_size=batch_size,
                                                        class_mode='categorical')
for data_batch, labels_batch in train_generator:
    print('data batch shape:', data_batch.shape)
    print('labels batch shape:', labels_batch.shape)
    break
train_sample = train_generator.samples
valid_sample = valid_generator.samples
# Out:
# Found 2323 images belonging to 5 classes.
# Found 500 images belonging to 5 classes.
# data batch shape: (24, 300, 300, 3)
# labels batch shape: (24, 5)

# %%
loop_start = time.time()
count = 0

for i in range(len(Conv2D_size)): #len(Conv2D_size)
    for j in range(1, 2): #len(drop_out)
        for k in range(0, 1): #len(l2_ratio)
            for m in range(3, 4): #len(optimizer)
                if count == 0:
                    count += 1
                    continue
                model_name = f'Model_{Conv2D_size[i]}-{drop_out[j]}-{l2_ratio[k]}-{optimizer[m]}'
                model = create_model(model_name, Conv2D_size[i], pic_size, l2_ratio[k], pool_size, drop_out[j])
                create_compile(optimizer[m])
                history = model.fit(train_generator, epochs=epochs, verbose=1,
                                    steps_per_epoch=int(train_sample/batch_size),
                                    validation_data=valid_generator,
                                    validation_steps=int(valid_sample/batch_size))
                id_li = []
                flower_class = []
                for n in range(len(list(unknown_dict.keys()))):
                    serial = list(unknown_dict.keys())[n]
                    pred = model.predict(unknown_dict[serial])[0]
                    id_li.append(serial)
                    flower_class.append(list(pred).index(max(pred)))
                    pred_result_df = pd.DataFrame(columns=['id', 'flower_class'])
                    pred_result_df['id'] = id_li
                    pred_result_df['flower_class'] = flower_class
                pred_result_df['flower_class'].value_counts().sort_index()
                pred_result_df.to_csv(f'model/FS_{fn_serial}/pred_result_FS_{i}-{j}-{k}-{m}.csv', index=False)
                train_acc = model.history.history["accuracy"]
                valid_acc = model.history.history["val_accuracy"]
                np.save(f'model/FS_{fn_serial}/History_{i}-{j}-{k}-{m}.npy', [train_acc, valid_acc])
                plt.figure(figsize=(10,8))
                plt.title(f'Accuracy_{i}-{j}-{k}-{m}')
                plt.ylim([0, 1])
                plt.xlim([0, 50])
                plt.plot(train_acc, label = 'train_acc')
                plt.plot(valid_acc, label = 'valid_acc')
                plt.legend()
                plt.savefig(f'model/FS_{fn_serial}/Accuracy_{i}-{j}-{k}-{m}.png')
                plt.clf()
                #plt.show()
                count += 1
                print(f'{count}/{total_item}, Model_{i}-{j}-{k}-{m} done. {happy_time(loop_start, time.time())}')
# Out:
# Epoch 1/100
# 96/96 [==============================] - 43s 450ms/step - loss: 2.4918 - accuracy: 0.3123 - val_loss: 1.5113 - val_accuracy: 0.3583
# Epoch 2/100
# 96/96 [==============================] - 49s 511ms/step - loss: 1.3907 - accuracy: 0.4167 - val_loss: 1.1304 - val_accuracy: 0.5189
# Epoch 3/100
# 96/96 [==============================] - 50s 523ms/step - loss: 1.2519 - accuracy: 0.5007 - val_loss: 0.9553 - val_accuracy: 0.5945
# Epoch 4/100
# 96/96 [==============================] - 49s 513ms/step - loss: 1.1874 - accuracy: 0.5598 - val_loss: 1.1934 - val_accuracy: 0.5294
# Epoch 5/100
# 96/96 [==============================] - 48s 497ms/step - loss: 1.0927 - accuracy: 0.5981 - val_loss: 1.1831 - val_accuracy: 0.6218
# Epoch 6/100
# 96/96 [==============================] - 45s 470ms/step - loss: 1.0783 - accuracy: 0.6016 - val_loss: 1.1176 - val_accuracy: 0.6555
# Epoch 7/100
# 96/96 [==============================] - 44s 463ms/step - loss: 1.0314 - accuracy: 0.6359 - val_loss: 1.6537 - val_accuracy: 0.5630
# Epoch 8/100
# 96/96 [==============================] - 45s 466ms/step - loss: 0.9901 - accuracy: 0.6485 - val_loss: 0.9366 - val_accuracy: 0.6639
# Epoch 9/100
# 96/96 [==============================] - 44s 460ms/step - loss: 0.9833 - accuracy: 0.6502 - val_loss: 0.8206 - val_accuracy: 0.7164
# Epoch 10/100
# 96/96 [==============================] - 43s 443ms/step - loss: 0.9712 - accuracy: 0.6582 - val_loss: 0.9526 - val_accuracy: 0.6513
# Epoch 11/100
# 96/96 [==============================] - 42s 435ms/step - loss: 0.9530 - accuracy: 0.6651 - val_loss: 0.7702 - val_accuracy: 0.6870
# Epoch 12/100
# 96/96 [==============================] - 41s 430ms/step - loss: 0.9304 - accuracy: 0.6929 - val_loss: 0.3984 - val_accuracy: 0.7185
# Epoch 13/100
# 96/96 [==============================] - 41s 423ms/step - loss: 0.9512 - accuracy: 0.6799 - val_loss: 0.8019 - val_accuracy: 0.6996
# Epoch 14/100
# 96/96 [==============================] - 40s 417ms/step - loss: 0.8845 - accuracy: 0.7012 - val_loss: 1.0244 - val_accuracy: 0.6912
# Epoch 15/100
# 96/96 [==============================] - 40s 417ms/step - loss: 0.8848 - accuracy: 0.7033 - val_loss: 0.5183 - val_accuracy: 0.7689
# Epoch 16/100
# 96/96 [==============================] - 40s 414ms/step - loss: 0.8761 - accuracy: 0.7007 - val_loss: 0.8102 - val_accuracy: 0.7437
# Epoch 17/100
# 96/96 [==============================] - 40s 414ms/step - loss: 0.8505 - accuracy: 0.7174 - val_loss: 0.8948 - val_accuracy: 0.6471
# Epoch 18/100
# 96/96 [==============================] - 40s 416ms/step - loss: 0.8753 - accuracy: 0.7149 - val_loss: 0.7943 - val_accuracy: 0.7290
# Epoch 19/100
# 96/96 [==============================] - 40s 415ms/step - loss: 0.8557 - accuracy: 0.7112 - val_loss: 1.1577 - val_accuracy: 0.6303
# Epoch 20/100
# 96/96 [==============================] - 40s 417ms/step - loss: 0.8553 - accuracy: 0.7225 - val_loss: 0.7371 - val_accuracy: 0.7059
# Epoch 21/100
# 96/96 [==============================] - 40s 418ms/step - loss: 0.8133 - accuracy: 0.7303 - val_loss: 1.3417 - val_accuracy: 0.6513
# Epoch 22/100
# 96/96 [==============================] - 40s 415ms/step - loss: 0.8302 - accuracy: 0.7308 - val_loss: 0.7658 - val_accuracy: 0.7188
# Epoch 23/100
# 96/96 [==============================] - 44s 463ms/step - loss: 0.7900 - accuracy: 0.7455 - val_loss: 0.7924 - val_accuracy: 0.7206
# Epoch 24/100
# 96/96 [==============================] - 43s 449ms/step - loss: 0.8009 - accuracy: 0.7429 - val_loss: 0.9686 - val_accuracy: 0.7269
# Epoch 25/100
# 96/96 [==============================] - 43s 443ms/step - loss: 0.7892 - accuracy: 0.7442 - val_loss: 0.9278 - val_accuracy: 0.7206
# Epoch 26/100
# 96/96 [==============================] - 43s 444ms/step - loss: 0.7638 - accuracy: 0.7444 - val_loss: 1.2154 - val_accuracy: 0.6555
# Epoch 27/100
# 96/96 [==============================] - 43s 444ms/step - loss: 0.8114 - accuracy: 0.7377 - val_loss: 0.7621 - val_accuracy: 0.7416
# Epoch 28/100
# 96/96 [==============================] - 41s 432ms/step - loss: 0.7751 - accuracy: 0.7489 - val_loss: 1.0925 - val_accuracy: 0.7563
# Epoch 29/100
# 96/96 [==============================] - 41s 428ms/step - loss: 0.7686 - accuracy: 0.7555 - val_loss: 0.9018 - val_accuracy: 0.7920
# Epoch 30/100
# 96/96 [==============================] - 41s 427ms/step - loss: 0.7904 - accuracy: 0.7312 - val_loss: 0.5869 - val_accuracy: 0.6807
# Epoch 31/100
# 96/96 [==============================] - 40s 420ms/step - loss: 0.7322 - accuracy: 0.7647 - val_loss: 0.7863 - val_accuracy: 0.7416
# Epoch 32/100
# 96/96 [==============================] - 41s 423ms/step - loss: 0.7315 - accuracy: 0.7603 - val_loss: 0.7590 - val_accuracy: 0.7038
# Epoch 33/100
# 96/96 [==============================] - 40s 416ms/step - loss: 0.7720 - accuracy: 0.7512 - val_loss: 1.1759 - val_accuracy: 0.7374
# Epoch 34/100
# 96/96 [==============================] - 39s 410ms/step - loss: 0.7631 - accuracy: 0.7608 - val_loss: 0.6775 - val_accuracy: 0.7374
# Epoch 35/100
# 96/96 [==============================] - 40s 413ms/step - loss: 0.7329 - accuracy: 0.7687 - val_loss: 1.4042 - val_accuracy: 0.7080
# Epoch 36/100
# 96/96 [==============================] - 40s 417ms/step - loss: 0.7197 - accuracy: 0.7733 - val_loss: 1.2974 - val_accuracy: 0.6723
# Epoch 37/100
# 96/96 [==============================] - 40s 413ms/step - loss: 0.7663 - accuracy: 0.7616 - val_loss: 0.8027 - val_accuracy: 0.7227
# Epoch 38/100
# 96/96 [==============================] - 40s 419ms/step - loss: 0.7590 - accuracy: 0.7552 - val_loss: 0.8171 - val_accuracy: 0.7605
# Epoch 39/100
# 96/96 [==============================] - 40s 414ms/step - loss: 0.7178 - accuracy: 0.7707 - val_loss: 1.0490 - val_accuracy: 0.7311
# Epoch 40/100
# 96/96 [==============================] - 40s 415ms/step - loss: 0.7212 - accuracy: 0.7664 - val_loss: 1.2980 - val_accuracy: 0.7248
# Epoch 41/100
# 96/96 [==============================] - 40s 419ms/step - loss: 0.7192 - accuracy: 0.7799 - val_loss: 1.0227 - val_accuracy: 0.7647
# Epoch 42/100
# 96/96 [==============================] - 40s 418ms/step - loss: 0.7001 - accuracy: 0.7772 - val_loss: 0.8573 - val_accuracy: 0.6597
# Epoch 43/100
# 96/96 [==============================] - 40s 419ms/step - loss: 0.6979 - accuracy: 0.7734 - val_loss: 1.0509 - val_accuracy: 0.7021
# Epoch 44/100
# 96/96 [==============================] - 44s 459ms/step - loss: 0.7379 - accuracy: 0.7769 - val_loss: 0.9488 - val_accuracy: 0.7836
# Epoch 45/100
# 96/96 [==============================] - 43s 448ms/step - loss: 0.7351 - accuracy: 0.7616 - val_loss: 0.6276 - val_accuracy: 0.7059
# Epoch 46/100
# 96/96 [==============================] - 43s 446ms/step - loss: 0.6797 - accuracy: 0.7838 - val_loss: 0.6833 - val_accuracy: 0.7290
# Epoch 47/100
# 96/96 [==============================] - 42s 440ms/step - loss: 0.6804 - accuracy: 0.7751 - val_loss: 0.6764 - val_accuracy: 0.7353
# Epoch 48/100
# 96/96 [==============================] - 42s 433ms/step - loss: 0.6940 - accuracy: 0.7860 - val_loss: 0.7644 - val_accuracy: 0.7311
# Epoch 49/100
# 96/96 [==============================] - 42s 437ms/step - loss: 0.6978 - accuracy: 0.7756 - val_loss: 0.6918 - val_accuracy: 0.7563
# Epoch 50/100
# 96/96 [==============================] - 42s 434ms/step - loss: 0.7193 - accuracy: 0.7755 - val_loss: 0.5215 - val_accuracy: 0.7794
# Epoch 51/100
# 96/96 [==============================] - 41s 427ms/step - loss: 0.6588 - accuracy: 0.7956 - val_loss: 0.5007 - val_accuracy: 0.7542
# Epoch 52/100
# 96/96 [==============================] - 41s 423ms/step - loss: 0.7374 - accuracy: 0.7699 - val_loss: 0.8918 - val_accuracy: 0.7458
# Epoch 53/100
# 96/96 [==============================] - 40s 420ms/step - loss: 0.6683 - accuracy: 0.7916 - val_loss: 0.8873 - val_accuracy: 0.7479
# Epoch 54/100
# 96/96 [==============================] - 40s 415ms/step - loss: 0.6725 - accuracy: 0.7999 - val_loss: 0.7134 - val_accuracy: 0.7542
# Epoch 55/100
# 96/96 [==============================] - 40s 415ms/step - loss: 0.6695 - accuracy: 0.7860 - val_loss: 0.5825 - val_accuracy: 0.7458
# Epoch 56/100
# 96/96 [==============================] - 40s 415ms/step - loss: 0.7001 - accuracy: 0.7768 - val_loss: 0.6544 - val_accuracy: 0.7647
# Epoch 57/100
# 96/96 [==============================] - 40s 415ms/step - loss: 0.6567 - accuracy: 0.7947 - val_loss: 0.7315 - val_accuracy: 0.7689
# Epoch 58/100
# 96/96 [==============================] - 40s 416ms/step - loss: 0.7054 - accuracy: 0.7816 - val_loss: 1.1989 - val_accuracy: 0.7542
# Epoch 59/100
# 96/96 [==============================] - 40s 420ms/step - loss: 0.6554 - accuracy: 0.7995 - val_loss: 0.8869 - val_accuracy: 0.7458
# Epoch 60/100
# 96/96 [==============================] - 40s 417ms/step - loss: 0.7144 - accuracy: 0.7908 - val_loss: 0.8862 - val_accuracy: 0.7626
# Epoch 61/100
# 96/96 [==============================] - 40s 417ms/step - loss: 0.6530 - accuracy: 0.8016 - val_loss: 1.0416 - val_accuracy: 0.7311
# Epoch 62/100
# 96/96 [==============================] - 40s 421ms/step - loss: 0.6645 - accuracy: 0.7999 - val_loss: 1.1046 - val_accuracy: 0.7059
# Epoch 63/100
# 96/96 [==============================] - 40s 415ms/step - loss: 0.6585 - accuracy: 0.8003 - val_loss: 1.2411 - val_accuracy: 0.5777
# Epoch 64/100
# 96/96 [==============================] - 41s 427ms/step - loss: 0.6898 - accuracy: 0.7860 - val_loss: 0.6380 - val_accuracy: 0.7458
# Epoch 65/100
# 96/96 [==============================] - 45s 464ms/step - loss: 0.7085 - accuracy: 0.7842 - val_loss: 0.9173 - val_accuracy: 0.7017
# Epoch 66/100
# 96/96 [==============================] - 43s 446ms/step - loss: 0.6696 - accuracy: 0.7977 - val_loss: 0.6369 - val_accuracy: 0.7374
# Epoch 67/100
# 96/96 [==============================] - 43s 448ms/step - loss: 0.6581 - accuracy: 0.8003 - val_loss: 0.9537 - val_accuracy: 0.7773
# Epoch 68/100
# 96/96 [==============================] - 42s 439ms/step - loss: 0.6296 - accuracy: 0.8152 - val_loss: 0.7567 - val_accuracy: 0.7542
# Epoch 69/100
# 96/96 [==============================] - 42s 441ms/step - loss: 0.6925 - accuracy: 0.7982 - val_loss: 0.7015 - val_accuracy: 0.8109
# Epoch 70/100
# 96/96 [==============================] - 42s 439ms/step - loss: 0.7350 - accuracy: 0.7925 - val_loss: 0.8226 - val_accuracy: 0.7206
# Epoch 71/100
# 96/96 [==============================] - 41s 429ms/step - loss: 0.6234 - accuracy: 0.8178 - val_loss: 0.7235 - val_accuracy: 0.7899
# Epoch 72/100
# 96/96 [==============================] - 41s 427ms/step - loss: 0.6349 - accuracy: 0.8177 - val_loss: 1.3839 - val_accuracy: 0.7164
# Epoch 73/100
# 96/96 [==============================] - 41s 425ms/step - loss: 0.6464 - accuracy: 0.7986 - val_loss: 0.8027 - val_accuracy: 0.7815
# Epoch 74/100
# 96/96 [==============================] - 40s 419ms/step - loss: 0.6501 - accuracy: 0.7986 - val_loss: 1.0328 - val_accuracy: 0.7206
# Epoch 75/100
# 96/96 [==============================] - 40s 414ms/step - loss: 0.6531 - accuracy: 0.8060 - val_loss: 0.7378 - val_accuracy: 0.7227
# Epoch 76/100
# 96/96 [==============================] - 39s 408ms/step - loss: 0.6254 - accuracy: 0.8095 - val_loss: 0.4724 - val_accuracy: 0.7794
# Epoch 77/100
# 96/96 [==============================] - 39s 409ms/step - loss: 0.6251 - accuracy: 0.8099 - val_loss: 1.6179 - val_accuracy: 0.7332
# Epoch 78/100
# 96/96 [==============================] - 39s 411ms/step - loss: 0.6175 - accuracy: 0.8003 - val_loss: 0.5786 - val_accuracy: 0.7794
# Epoch 79/100
# 96/96 [==============================] - 41s 432ms/step - loss: 0.6277 - accuracy: 0.8143 - val_loss: 0.3191 - val_accuracy: 0.7920
# Epoch 80/100
# 96/96 [==============================] - 41s 423ms/step - loss: 0.6380 - accuracy: 0.7995 - val_loss: 0.8805 - val_accuracy: 0.7605
# Epoch 81/100
# 96/96 [==============================] - 40s 422ms/step - loss: 0.5869 - accuracy: 0.8191 - val_loss: 1.0722 - val_accuracy: 0.6849
# Epoch 82/100
# 96/96 [==============================] - 40s 418ms/step - loss: 0.6234 - accuracy: 0.8169 - val_loss: 0.4245 - val_accuracy: 0.7773
# Epoch 83/100
# 96/96 [==============================] - 40s 413ms/step - loss: 0.6716 - accuracy: 0.8191 - val_loss: 0.5095 - val_accuracy: 0.7962
# Epoch 84/100
# 96/96 [==============================] - 40s 412ms/step - loss: 0.6007 - accuracy: 0.8282 - val_loss: 0.9996 - val_accuracy: 0.7689
# Epoch 85/100
# 96/96 [==============================] - 40s 418ms/step - loss: 0.6263 - accuracy: 0.8073 - val_loss: 0.5932 - val_accuracy: 0.7604
# Epoch 86/100
# 96/96 [==============================] - 44s 455ms/step - loss: 0.6297 - accuracy: 0.8121 - val_loss: 0.7450 - val_accuracy: 0.7857
# Epoch 87/100
# 96/96 [==============================] - 43s 448ms/step - loss: 0.6289 - accuracy: 0.8186 - val_loss: 0.7345 - val_accuracy: 0.7794
# Epoch 88/100
# 96/96 [==============================] - 42s 442ms/step - loss: 0.5995 - accuracy: 0.8199 - val_loss: 0.8978 - val_accuracy: 0.7731
# Epoch 89/100
# 96/96 [==============================] - 42s 440ms/step - loss: 0.5841 - accuracy: 0.8204 - val_loss: 1.6287 - val_accuracy: 0.6744
# Epoch 90/100
# 96/96 [==============================] - 42s 438ms/step - loss: 0.6826 - accuracy: 0.8012 - val_loss: 1.1241 - val_accuracy: 0.7878
# Epoch 91/100
# 96/96 [==============================] - 41s 432ms/step - loss: 0.6304 - accuracy: 0.8208 - val_loss: 0.9594 - val_accuracy: 0.7437
# Epoch 92/100
# 96/96 [==============================] - 41s 429ms/step - loss: 0.6132 - accuracy: 0.8129 - val_loss: 0.9791 - val_accuracy: 0.7752
# Epoch 93/100
# 96/96 [==============================] - 41s 427ms/step - loss: 0.6074 - accuracy: 0.8212 - val_loss: 0.6907 - val_accuracy: 0.7941
# Epoch 94/100
# 96/96 [==============================] - 40s 420ms/step - loss: 0.6380 - accuracy: 0.8112 - val_loss: 0.9512 - val_accuracy: 0.7899
# Epoch 95/100
# 96/96 [==============================] - 41s 428ms/step - loss: 0.5894 - accuracy: 0.8264 - val_loss: 0.3456 - val_accuracy: 0.8004
# Epoch 96/100
# 96/96 [==============================] - 40s 419ms/step - loss: 0.6136 - accuracy: 0.8221 - val_loss: 0.7596 - val_accuracy: 0.7206
# Epoch 97/100
# 96/96 [==============================] - 40s 417ms/step - loss: 0.6282 - accuracy: 0.8134 - val_loss: 0.3588 - val_accuracy: 0.8130
# Epoch 98/100
# 96/96 [==============================] - 40s 415ms/step - loss: 0.5972 - accuracy: 0.8225 - val_loss: 0.5989 - val_accuracy: 0.7668
# Epoch 99/100
# 96/96 [==============================] - 43s 450ms/step - loss: 0.6159 - accuracy: 0.8212 - val_loss: 0.8232 - val_accuracy: 0.7521
# Epoch 100/100
# 96/96 [==============================] - 44s 458ms/step - loss: 0.6083 - accuracy: 0.8212 - val_loss: 0.8802 - val_accuracy: 0.7710
# 2/72, Model_1-1-0-3 done. Process time == 4168s == 1H 9m 28s
# Epoch 1/100
# 96/96 [==============================] - 44s 461ms/step - loss: 2.2971 - accuracy: 0.3184 - val_loss: 1.4304 - val_accuracy: 0.3313
# Epoch 2/100
# 96/96 [==============================] - 48s 505ms/step - loss: 1.5566 - accuracy: 0.3706 - val_loss: 1.2207 - val_accuracy: 0.2731
# Epoch 3/100
# 96/96 [==============================] - 47s 494ms/step - loss: 1.4755 - accuracy: 0.4189 - val_loss: 1.5119 - val_accuracy: 0.3067
# Epoch 4/100
# 96/96 [==============================] - 47s 485ms/step - loss: 1.4105 - accuracy: 0.4463 - val_loss: 0.9777 - val_accuracy: 0.4706
# Epoch 5/100
# 96/96 [==============================] - 46s 480ms/step - loss: 1.3450 - accuracy: 0.4976 - val_loss: 1.1710 - val_accuracy: 0.5672
# Epoch 6/100
# 96/96 [==============================] - 46s 476ms/step - loss: 1.2026 - accuracy: 0.5298 - val_loss: 1.2641 - val_accuracy: 0.5462
# Epoch 7/100
# 96/96 [==============================] - 45s 468ms/step - loss: 1.1928 - accuracy: 0.5528 - val_loss: 1.4268 - val_accuracy: 0.4433
# Epoch 8/100
# 96/96 [==============================] - 45s 467ms/step - loss: 1.1067 - accuracy: 0.5859 - val_loss: 1.0766 - val_accuracy: 0.6113
# Epoch 9/100
# 96/96 [==============================] - 45s 466ms/step - loss: 1.0906 - accuracy: 0.5963 - val_loss: 1.5181 - val_accuracy: 0.5336
# Epoch 10/100
# 96/96 [==============================] - 46s 475ms/step - loss: 1.0540 - accuracy: 0.6216 - val_loss: 1.0732 - val_accuracy: 0.6555
# Epoch 11/100
# 96/96 [==============================] - 44s 459ms/step - loss: 1.0755 - accuracy: 0.6111 - val_loss: 1.2320 - val_accuracy: 0.6366
# Epoch 12/100
# 96/96 [==============================] - 45s 473ms/step - loss: 1.0363 - accuracy: 0.6364 - val_loss: 0.7991 - val_accuracy: 0.6513
# Epoch 13/100
# 96/96 [==============================] - 42s 440ms/step - loss: 0.9848 - accuracy: 0.6459 - val_loss: 0.8889 - val_accuracy: 0.6576
# Epoch 14/100
# 96/96 [==============================] - 43s 447ms/step - loss: 0.9749 - accuracy: 0.6538 - val_loss: 0.7365 - val_accuracy: 0.6723
# Epoch 15/100
# 96/96 [==============================] - 43s 449ms/step - loss: 0.9665 - accuracy: 0.6677 - val_loss: 0.9094 - val_accuracy: 0.6786
# Epoch 16/100
# 96/96 [==============================] - 41s 430ms/step - loss: 0.9228 - accuracy: 0.6686 - val_loss: 0.8996 - val_accuracy: 0.6639
# Epoch 17/100
# 96/96 [==============================] - 41s 428ms/step - loss: 0.9669 - accuracy: 0.6768 - val_loss: 0.9654 - val_accuracy: 0.6849
# Epoch 18/100
# 96/96 [==============================] - 41s 428ms/step - loss: 0.9363 - accuracy: 0.6699 - val_loss: 0.8791 - val_accuracy: 0.6786
# Epoch 19/100
# 96/96 [==============================] - 41s 425ms/step - loss: 0.9162 - accuracy: 0.6777 - val_loss: 0.4890 - val_accuracy: 0.6723
# Epoch 20/100
# 96/96 [==============================] - 41s 424ms/step - loss: 0.9086 - accuracy: 0.6773 - val_loss: 0.6454 - val_accuracy: 0.6954
# Epoch 21/100
# 96/96 [==============================] - 40s 419ms/step - loss: 0.8932 - accuracy: 0.6773 - val_loss: 1.2739 - val_accuracy: 0.6723
# Epoch 22/100
# 96/96 [==============================] - 42s 436ms/step - loss: 0.8716 - accuracy: 0.6933 - val_loss: 0.7416 - val_accuracy: 0.7208
# Epoch 23/100
# 96/96 [==============================] - 45s 465ms/step - loss: 0.8825 - accuracy: 0.6977 - val_loss: 0.6402 - val_accuracy: 0.7206
# Epoch 24/100
# 96/96 [==============================] - 44s 454ms/step - loss: 0.8455 - accuracy: 0.7020 - val_loss: 0.8646 - val_accuracy: 0.6702
# Epoch 25/100
# 96/96 [==============================] - 44s 459ms/step - loss: 0.8574 - accuracy: 0.7190 - val_loss: 0.7721 - val_accuracy: 0.7038
# Epoch 26/100
# 96/96 [==============================] - 43s 449ms/step - loss: 0.8258 - accuracy: 0.7181 - val_loss: 0.7788 - val_accuracy: 0.7164
# Epoch 27/100
# 96/96 [==============================] - 42s 436ms/step - loss: 0.8684 - accuracy: 0.7064 - val_loss: 0.8230 - val_accuracy: 0.6849
# Epoch 28/100
# 96/96 [==============================] - 43s 443ms/step - loss: 0.8178 - accuracy: 0.7181 - val_loss: 1.2437 - val_accuracy: 0.6618
# Epoch 29/100
# 96/96 [==============================] - 43s 443ms/step - loss: 0.8467 - accuracy: 0.7131 - val_loss: 1.0583 - val_accuracy: 0.6576
# Epoch 30/100
# 96/96 [==============================] - 41s 428ms/step - loss: 0.8016 - accuracy: 0.7371 - val_loss: 1.2543 - val_accuracy: 0.6870
# Epoch 31/100
# 96/96 [==============================] - 41s 432ms/step - loss: 0.7858 - accuracy: 0.7425 - val_loss: 0.6077 - val_accuracy: 0.6828
# Epoch 32/100
# 96/96 [==============================] - 41s 431ms/step - loss: 0.8630 - accuracy: 0.7101 - val_loss: 0.8817 - val_accuracy: 0.6828
# Epoch 33/100
# 96/96 [==============================] - 40s 419ms/step - loss: 0.8288 - accuracy: 0.7153 - val_loss: 0.6287 - val_accuracy: 0.7206
# Epoch 34/100
# 96/96 [==============================] - 40s 414ms/step - loss: 0.8396 - accuracy: 0.7286 - val_loss: 0.6420 - val_accuracy: 0.6975
# Epoch 35/100
# 96/96 [==============================] - 40s 414ms/step - loss: 0.8126 - accuracy: 0.7222 - val_loss: 0.9826 - val_accuracy: 0.6092
# Epoch 36/100
# 96/96 [==============================] - 41s 423ms/step - loss: 0.8325 - accuracy: 0.7234 - val_loss: 1.5703 - val_accuracy: 0.6345
# Epoch 37/100
# 96/96 [==============================] - 41s 427ms/step - loss: 0.7899 - accuracy: 0.7319 - val_loss: 1.0431 - val_accuracy: 0.7038
# Epoch 38/100
# 96/96 [==============================] - 40s 418ms/step - loss: 0.7604 - accuracy: 0.7512 - val_loss: 1.2002 - val_accuracy: 0.6870
# Epoch 39/100
# 96/96 [==============================] - 40s 417ms/step - loss: 0.7953 - accuracy: 0.7442 - val_loss: 0.9695 - val_accuracy: 0.7542
# Epoch 40/100
# 96/96 [==============================] - 40s 417ms/step - loss: 0.7713 - accuracy: 0.7438 - val_loss: 0.9658 - val_accuracy: 0.7038
# Epoch 41/100
# 96/96 [==============================] - 40s 421ms/step - loss: 0.7727 - accuracy: 0.7477 - val_loss: 0.6737 - val_accuracy: 0.7185
# Epoch 42/100
# 96/96 [==============================] - 40s 421ms/step - loss: 0.7775 - accuracy: 0.7334 - val_loss: 0.7481 - val_accuracy: 0.7101
# Epoch 43/100
# 96/96 [==============================] - 40s 418ms/step - loss: 0.7573 - accuracy: 0.7551 - val_loss: 0.8992 - val_accuracy: 0.7271
# Epoch 44/100
# 96/96 [==============================] - 44s 459ms/step - loss: 0.7947 - accuracy: 0.7490 - val_loss: 0.9482 - val_accuracy: 0.6912
# Epoch 45/100
# 96/96 [==============================] - 43s 453ms/step - loss: 0.7350 - accuracy: 0.7604 - val_loss: 0.6600 - val_accuracy: 0.7185
# Epoch 46/100
# 96/96 [==============================] - 43s 448ms/step - loss: 0.7517 - accuracy: 0.7498 - val_loss: 0.4585 - val_accuracy: 0.7038
# Epoch 47/100
# 96/96 [==============================] - 43s 443ms/step - loss: 0.7264 - accuracy: 0.7786 - val_loss: 0.7592 - val_accuracy: 0.7227
# Epoch 48/100
# 96/96 [==============================] - 42s 441ms/step - loss: 0.7674 - accuracy: 0.7482 - val_loss: 0.5558 - val_accuracy: 0.7437
# Epoch 49/100
# 96/96 [==============================] - 42s 441ms/step - loss: 0.7228 - accuracy: 0.7691 - val_loss: 0.6456 - val_accuracy: 0.7206
# Epoch 50/100
# 96/96 [==============================] - 41s 432ms/step - loss: 0.7556 - accuracy: 0.7625 - val_loss: 1.5176 - val_accuracy: 0.6345
# Epoch 51/100
# 96/96 [==============================] - 41s 432ms/step - loss: 0.7533 - accuracy: 0.7608 - val_loss: 0.8598 - val_accuracy: 0.6975
# Epoch 52/100
# 96/96 [==============================] - 41s 426ms/step - loss: 0.7003 - accuracy: 0.7768 - val_loss: 0.6728 - val_accuracy: 0.7038
# Epoch 53/100
# 96/96 [==============================] - 40s 419ms/step - loss: 0.7634 - accuracy: 0.7517 - val_loss: 1.3548 - val_accuracy: 0.7395
# Epoch 54/100
# 96/96 [==============================] - 40s 418ms/step - loss: 0.6582 - accuracy: 0.7877 - val_loss: 0.5633 - val_accuracy: 0.7416
# Epoch 55/100
# 96/96 [==============================] - 40s 416ms/step - loss: 0.7311 - accuracy: 0.7600 - val_loss: 1.1143 - val_accuracy: 0.7710
# Epoch 56/100
# 96/96 [==============================] - 40s 412ms/step - loss: 0.7373 - accuracy: 0.7686 - val_loss: 1.3573 - val_accuracy: 0.7185
# Epoch 57/100
# 96/96 [==============================] - 40s 417ms/step - loss: 0.6940 - accuracy: 0.7786 - val_loss: 1.2947 - val_accuracy: 0.7185
# Epoch 58/100
# 96/96 [==============================] - 40s 416ms/step - loss: 0.7006 - accuracy: 0.7777 - val_loss: 0.4264 - val_accuracy: 0.7143
# Epoch 59/100
# 96/96 [==============================] - 40s 415ms/step - loss: 0.7016 - accuracy: 0.7625 - val_loss: 2.1506 - val_accuracy: 0.7353
# Epoch 60/100
# 96/96 [==============================] - 40s 416ms/step - loss: 0.6700 - accuracy: 0.7873 - val_loss: 0.9652 - val_accuracy: 0.7542
# Epoch 61/100
# 96/96 [==============================] - 40s 418ms/step - loss: 0.7201 - accuracy: 0.7700 - val_loss: 0.8260 - val_accuracy: 0.7395
# Epoch 62/100
# 96/96 [==============================] - 40s 414ms/step - loss: 0.6943 - accuracy: 0.7803 - val_loss: 0.6100 - val_accuracy: 0.7248
# Epoch 63/100
# 96/96 [==============================] - 40s 412ms/step - loss: 0.7257 - accuracy: 0.7742 - val_loss: 0.5960 - val_accuracy: 0.7248
# Epoch 64/100
# 96/96 [==============================] - 40s 418ms/step - loss: 0.6617 - accuracy: 0.7899 - val_loss: 0.9545 - val_accuracy: 0.7208
# Epoch 65/100
# 96/96 [==============================] - 44s 457ms/step - loss: 0.6885 - accuracy: 0.7812 - val_loss: 0.5150 - val_accuracy: 0.7437
# Epoch 66/100
# 96/96 [==============================] - 43s 447ms/step - loss: 0.7005 - accuracy: 0.7934 - val_loss: 0.6605 - val_accuracy: 0.7206
# Epoch 67/100
# 96/96 [==============================] - 42s 441ms/step - loss: 0.6775 - accuracy: 0.7830 - val_loss: 0.5088 - val_accuracy: 0.7080
# Epoch 68/100
# 96/96 [==============================] - 42s 438ms/step - loss: 0.7172 - accuracy: 0.7712 - val_loss: 0.8706 - val_accuracy: 0.7353
# Epoch 69/100
# 96/96 [==============================] - 42s 435ms/step - loss: 0.6885 - accuracy: 0.7742 - val_loss: 0.7593 - val_accuracy: 0.7332
# Epoch 70/100
# 96/96 [==============================] - 41s 429ms/step - loss: 0.6363 - accuracy: 0.7986 - val_loss: 0.8497 - val_accuracy: 0.7101
# Epoch 71/100
# 96/96 [==============================] - 41s 429ms/step - loss: 0.6955 - accuracy: 0.7895 - val_loss: 0.5654 - val_accuracy: 0.7479
# Epoch 72/100
# 96/96 [==============================] - 45s 471ms/step - loss: 0.7208 - accuracy: 0.7825 - val_loss: 0.5797 - val_accuracy: 0.7395
# Epoch 73/100
# 96/96 [==============================] - 41s 423ms/step - loss: 0.6705 - accuracy: 0.7951 - val_loss: 0.7570 - val_accuracy: 0.7206
# Epoch 74/100
# 96/96 [==============================] - 40s 419ms/step - loss: 0.6508 - accuracy: 0.7995 - val_loss: 0.7787 - val_accuracy: 0.7059
# Epoch 75/100
# 96/96 [==============================] - 40s 417ms/step - loss: 0.6289 - accuracy: 0.7977 - val_loss: 0.7618 - val_accuracy: 0.7521
# Epoch 76/100
# 96/96 [==============================] - 39s 410ms/step - loss: 0.6577 - accuracy: 0.7864 - val_loss: 0.5512 - val_accuracy: 0.7080
# Epoch 77/100
# 96/96 [==============================] - 39s 410ms/step - loss: 0.6435 - accuracy: 0.7912 - val_loss: 0.8664 - val_accuracy: 0.7206
# Epoch 78/100
# 96/96 [==============================] - 40s 414ms/step - loss: 0.6664 - accuracy: 0.7969 - val_loss: 0.7086 - val_accuracy: 0.7290
# Epoch 79/100
# 96/96 [==============================] - 39s 410ms/step - loss: 0.6677 - accuracy: 0.7960 - val_loss: 0.7840 - val_accuracy: 0.7164
# Epoch 80/100
# 96/96 [==============================] - 39s 410ms/step - loss: 0.6511 - accuracy: 0.7925 - val_loss: 0.9357 - val_accuracy: 0.7248
# Epoch 81/100
# 96/96 [==============================] - 39s 410ms/step - loss: 0.6677 - accuracy: 0.8056 - val_loss: 1.3026 - val_accuracy: 0.7206
# Epoch 82/100
# 96/96 [==============================] - 39s 411ms/step - loss: 0.6480 - accuracy: 0.8077 - val_loss: 0.7911 - val_accuracy: 0.6975
# Epoch 83/100
# 96/96 [==============================] - 39s 411ms/step - loss: 0.6479 - accuracy: 0.7943 - val_loss: 1.7150 - val_accuracy: 0.7500
# Epoch 84/100
# 96/96 [==============================] - 39s 409ms/step - loss: 0.6826 - accuracy: 0.7943 - val_loss: 0.9923 - val_accuracy: 0.6891
# Epoch 85/100
# 96/96 [==============================] - 39s 411ms/step - loss: 0.6877 - accuracy: 0.7973 - val_loss: 1.0378 - val_accuracy: 0.7312
# Epoch 86/100
# 96/96 [==============================] - 43s 453ms/step - loss: 0.6462 - accuracy: 0.7999 - val_loss: 1.3001 - val_accuracy: 0.7500
# Epoch 87/100
# 96/96 [==============================] - 43s 443ms/step - loss: 0.6768 - accuracy: 0.7990 - val_loss: 0.7341 - val_accuracy: 0.7500
# Epoch 88/100
# 96/96 [==============================] - 42s 440ms/step - loss: 0.6482 - accuracy: 0.8021 - val_loss: 1.4486 - val_accuracy: 0.6975
# Epoch 89/100
# 96/96 [==============================] - 42s 437ms/step - loss: 0.6721 - accuracy: 0.8112 - val_loss: 0.7176 - val_accuracy: 0.7395
# Epoch 90/100
# 96/96 [==============================] - 42s 433ms/step - loss: 0.6065 - accuracy: 0.8090 - val_loss: 0.9500 - val_accuracy: 0.7458
# Epoch 91/100
# 96/96 [==============================] - 41s 429ms/step - loss: 0.6307 - accuracy: 0.8090 - val_loss: 0.4846 - val_accuracy: 0.7857
# Epoch 92/100
# 96/96 [==============================] - 41s 424ms/step - loss: 0.6357 - accuracy: 0.8086 - val_loss: 0.7678 - val_accuracy: 0.7563
# Epoch 93/100
# 96/96 [==============================] - 41s 422ms/step - loss: 0.6364 - accuracy: 0.8099 - val_loss: 0.8141 - val_accuracy: 0.7416
# Epoch 94/100
# 96/96 [==============================] - 40s 419ms/step - loss: 0.6393 - accuracy: 0.8056 - val_loss: 0.6277 - val_accuracy: 0.6765
# Epoch 95/100
# 96/96 [==============================] - 40s 415ms/step - loss: 0.6136 - accuracy: 0.8082 - val_loss: 2.1986 - val_accuracy: 0.7437
# Epoch 96/100
# 96/96 [==============================] - 39s 411ms/step - loss: 0.6096 - accuracy: 0.8195 - val_loss: 1.2269 - val_accuracy: 0.7185
# Epoch 97/100
# 96/96 [==============================] - 39s 407ms/step - loss: 0.6205 - accuracy: 0.8164 - val_loss: 0.4749 - val_accuracy: 0.7752
# Epoch 98/100
# 96/96 [==============================] - 39s 407ms/step - loss: 0.6350 - accuracy: 0.8138 - val_loss: 1.0542 - val_accuracy: 0.6429
# Epoch 99/100
# 96/96 [==============================] - 43s 448ms/step - loss: 0.6156 - accuracy: 0.8169 - val_loss: 0.7180 - val_accuracy: 0.7479
# Epoch 100/100
# 96/96 [==============================] - 43s 444ms/step - loss: 0.6499 - accuracy: 0.8047 - val_loss: 0.7528 - val_accuracy: 0.7479
# 3/72, Model_2-1-0-3 done. Process time == 8355s == 2H 19m 15s

# %%
'''
pred_result_df.to_csv(f'model/FS_{fn_serial}/pred_result_FS_{i}-{j}-{k}-{m}.csv', index=False)
train_acc = model.history.history["accuracy"]
valid_acc = model.history.history["val_accuracy"]
np.save(f'model/FS_{fn_serial}/History_{i}-{j}-{k}-{m}.npy', [train_acc, valid_acc])
plt.figure(figsize=(10,8))
plt.title(f'Accuracy_{i}-{j}-{k}-{m}')
plt.ylim([0, 1])
plt.xlim([0, 50])
plt.plot(train_acc, label = 'train_acc')
plt.plot(valid_acc, label = 'valid_acc')
plt.legend()
plt.savefig(f'model/FS_{fn_serial}/Accuracy_{i}-{j}-{k}-{m}.png')
plt.clf()
#plt.show()
count += 1
print(f'{count}/{total_item}, Model_{i}-{j}-{k}-{m} done. {happy_time(loop_start, time.time())}')
'''
# Out:
# '\npred_result_df.to_csv(f\'model/FS_{fn_serial}/pred_result_FS_{i}-{j}-{k}-{m}.csv\', index=False)\ntrain_acc = model.history.history["accuracy"]\nvalid_acc = model.history.history["val_accuracy"]\nnp.save(f\'model/FS_{fn_serial}/History_{i}-{j}-{k}-{m}.npy\', [train_acc, valid_acc])\nplt.figure(figsize=(10,8))\nplt.title(f\'Accuracy_{i}-{j}-{k}-{m}\')\nplt.ylim([0, 1])\nplt.xlim([0, 50])\nplt.plot(train_acc, label = \'train_acc\')\nplt.plot(valid_acc, label = \'valid_acc\')\nplt.legend()\nplt.savefig(f\'model/FS_{fn_serial}/Accuracy_{i}-{j}-{k}-{m}.png\')\nplt.clf()\n#plt.show()\ncount += 1\nprint(f\'{count}/{total_item}, Model_{i}-{j}-{k}-{m} done. {happy_time(loop_start, time.time())}\')\n'
