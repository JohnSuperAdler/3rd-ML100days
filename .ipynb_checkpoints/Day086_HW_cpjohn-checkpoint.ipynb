# %% [markdown]
# ## Work
# 1. 試比較 save_best_only 與否的差異
# 2. 請僅存入將 save_weights_only 設定為 True, 並嘗試 reset ipynb 並將模型與權重重新建回並預測 x_test

# %%
import os
import keras
from keras.layers import BatchNormalization
from keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt
# Disable GPU
os.environ["CUDA_VISIBLE_DEVICES"] = ""
# Out:
# Using TensorFlow backend.

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128]):
    input_layer = keras.layers.Input(input_shape)
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(input_layer)
            x = BatchNormalization()(x)
        else:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(x)
            x = BatchNormalization()(x)
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
## 超參數設定
LEARNING_RATE = 1e-3
EPOCHS = 50
BATCH_SIZE = 1024
MOMENTUM = 0.95

# %% [markdown]
# ## save_best_only=False

# %%
# 載入 Callbacks
model_ckpt = ModelCheckpoint(filepath="./tmp.h5", 
                             monitor="val_loss",
                             verbose=1,
                             save_best_only=False)

# %%
model = build_mlp(input_shape=x_train.shape[1:])
model.summary()
optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

model.fit(x_train, y_train, 
          epochs=EPOCHS, 
          batch_size=BATCH_SIZE, 
          validation_data=(x_test, y_test), 
          shuffle=True,
          callbacks=[model_ckpt]
         )

# Collect results
train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]
train_acc = model.history.history["accuracy"]
valid_acc = model.history.history["val_accuracy"]

# Load back
model = keras.models.load_model("./tmp.h5")
loss_loadback, acc_loadback = model.evaluate(x_test, y_test)
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 2s 41us/step - loss: 2.2064 - accuracy: 0.2676 - val_loss: 2.1523 - val_accuracy: 0.2214
#
# Epoch 00001: saving model to ./tmp.h5
# Epoch 2/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 1.7569 - accuracy: 0.3921 - val_loss: 1.9712 - val_accuracy: 0.3108
#
# Epoch 00002: saving model to ./tmp.h5
# Epoch 3/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 1.6334 - accuracy: 0.4296 - val_loss: 1.8349 - val_accuracy: 0.3673
#
# Epoch 00003: saving model to ./tmp.h5
# Epoch 4/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 1.5577 - accuracy: 0.4565 - val_loss: 1.7335 - val_accuracy: 0.4011
#
# Epoch 00004: saving model to ./tmp.h5
# Epoch 5/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 1.5054 - accuracy: 0.4762 - val_loss: 1.6584 - val_accuracy: 0.4171
#
# Epoch 00005: saving model to ./tmp.h5
# Epoch 6/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 1.4574 - accuracy: 0.4936 - val_loss: 1.6049 - val_accuracy: 0.4378
#
# Epoch 00006: saving model to ./tmp.h5
# Epoch 7/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 1.4170 - accuracy: 0.5073 - val_loss: 1.5715 - val_accuracy: 0.4441
#
# Epoch 00007: saving model to ./tmp.h5
# Epoch 8/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 1.3804 - accuracy: 0.5205 - val_loss: 1.5369 - val_accuracy: 0.4571
#
# Epoch 00008: saving model to ./tmp.h5
# Epoch 9/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 1.3466 - accuracy: 0.5318 - val_loss: 1.5314 - val_accuracy: 0.4565
#
# Epoch 00009: saving model to ./tmp.h5
# Epoch 10/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 1.3144 - accuracy: 0.5451 - val_loss: 1.5092 - val_accuracy: 0.4667
#
# Epoch 00010: saving model to ./tmp.h5
# Epoch 11/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 1.2855 - accuracy: 0.5556 - val_loss: 1.4968 - val_accuracy: 0.4648
#
# Epoch 00011: saving model to ./tmp.h5
# Epoch 12/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 1.2572 - accuracy: 0.5658 - val_loss: 1.4845 - val_accuracy: 0.4733
#
# Epoch 00012: saving model to ./tmp.h5
# Epoch 13/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 1.2304 - accuracy: 0.5746 - val_loss: 1.4847 - val_accuracy: 0.4713
#
# Epoch 00013: saving model to ./tmp.h5
# Epoch 14/50
# 50000/50000 [==============================] - 1s 30us/step - loss: 1.2045 - accuracy: 0.5828 - val_loss: 1.4842 - val_accuracy: 0.4783
#
# Epoch 00014: saving model to ./tmp.h5
# Epoch 15/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 1.1804 - accuracy: 0.5935 - val_loss: 1.4836 - val_accuracy: 0.4776
#
# Epoch 00015: saving model to ./tmp.h5
# Epoch 16/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 1.1566 - accuracy: 0.6033 - val_loss: 1.4850 - val_accuracy: 0.4753
#
# Epoch 00016: saving model to ./tmp.h5
# Epoch 17/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 1.1325 - accuracy: 0.6115 - val_loss: 1.4694 - val_accuracy: 0.4843
#
# Epoch 00017: saving model to ./tmp.h5
# Epoch 18/50
# 50000/50000 [==============================] - 1s 30us/step - loss: 1.1081 - accuracy: 0.6225 - val_loss: 1.4776 - val_accuracy: 0.4846
#
# Epoch 00018: saving model to ./tmp.h5
# Epoch 19/50
# 50000/50000 [==============================] - 1s 30us/step - loss: 1.0885 - accuracy: 0.6290 - val_loss: 1.4779 - val_accuracy: 0.4790
#
# Epoch 00019: saving model to ./tmp.h5
# Epoch 20/50
# 50000/50000 [==============================] - 1s 30us/step - loss: 1.0657 - accuracy: 0.6379 - val_loss: 1.4608 - val_accuracy: 0.4878
#
# Epoch 00020: saving model to ./tmp.h5
# Epoch 21/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 1.0436 - accuracy: 0.6467 - val_loss: 1.4630 - val_accuracy: 0.4860
#
# Epoch 00021: saving model to ./tmp.h5
# Epoch 22/50
# 50000/50000 [==============================] - 1s 30us/step - loss: 1.0194 - accuracy: 0.6539 - val_loss: 1.4721 - val_accuracy: 0.4835
#
# Epoch 00022: saving model to ./tmp.h5
# Epoch 23/50
# 50000/50000 [==============================] - 1s 30us/step - loss: 0.9992 - accuracy: 0.6657 - val_loss: 1.4692 - val_accuracy: 0.4825
#
# Epoch 00023: saving model to ./tmp.h5
# Epoch 24/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.9771 - accuracy: 0.6722 - val_loss: 1.4793 - val_accuracy: 0.4863
#
# Epoch 00024: saving model to ./tmp.h5
# Epoch 25/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.9571 - accuracy: 0.6797 - val_loss: 1.4813 - val_accuracy: 0.4839
#
# Epoch 00025: saving model to ./tmp.h5
# Epoch 26/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.9373 - accuracy: 0.6875 - val_loss: 1.4971 - val_accuracy: 0.4800
#
# Epoch 00026: saving model to ./tmp.h5
# Epoch 27/50
# 50000/50000 [==============================] - 1s 30us/step - loss: 0.9162 - accuracy: 0.6965 - val_loss: 1.5006 - val_accuracy: 0.4847
#
# Epoch 00027: saving model to ./tmp.h5
# Epoch 28/50
# 50000/50000 [==============================] - 2s 30us/step - loss: 0.8965 - accuracy: 0.7027 - val_loss: 1.4859 - val_accuracy: 0.4872
#
# Epoch 00028: saving model to ./tmp.h5
# Epoch 29/50
# 50000/50000 [==============================] - 1s 30us/step - loss: 0.8778 - accuracy: 0.7105 - val_loss: 1.4947 - val_accuracy: 0.4844
#
# Epoch 00029: saving model to ./tmp.h5
# Epoch 30/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.8557 - accuracy: 0.7213 - val_loss: 1.5051 - val_accuracy: 0.4838
#
# Epoch 00030: saving model to ./tmp.h5
# Epoch 31/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.8362 - accuracy: 0.7268 - val_loss: 1.5049 - val_accuracy: 0.4890
#
# Epoch 00031: saving model to ./tmp.h5
# Epoch 32/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.8156 - accuracy: 0.7351 - val_loss: 1.5198 - val_accuracy: 0.4821
#
# Epoch 00032: saving model to ./tmp.h5
# Epoch 33/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.7991 - accuracy: 0.7421 - val_loss: 1.5337 - val_accuracy: 0.4831
#
# Epoch 00033: saving model to ./tmp.h5
# Epoch 34/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.7790 - accuracy: 0.7505 - val_loss: 1.5309 - val_accuracy: 0.4887
#
# Epoch 00034: saving model to ./tmp.h5
# Epoch 35/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.7589 - accuracy: 0.7580 - val_loss: 1.5456 - val_accuracy: 0.4819
#
# Epoch 00035: saving model to ./tmp.h5
# Epoch 36/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.7383 - accuracy: 0.7647 - val_loss: 1.5430 - val_accuracy: 0.4858
#
# Epoch 00036: saving model to ./tmp.h5
# Epoch 37/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.7204 - accuracy: 0.7737 - val_loss: 1.5506 - val_accuracy: 0.4894
#
# Epoch 00037: saving model to ./tmp.h5
# Epoch 38/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.7011 - accuracy: 0.7815 - val_loss: 1.5640 - val_accuracy: 0.4901
#
# Epoch 00038: saving model to ./tmp.h5
# Epoch 39/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.6817 - accuracy: 0.7868 - val_loss: 1.5640 - val_accuracy: 0.4912
#
# Epoch 00039: saving model to ./tmp.h5
# Epoch 40/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.6660 - accuracy: 0.7944 - val_loss: 1.5835 - val_accuracy: 0.4880
#
# Epoch 00040: saving model to ./tmp.h5
# Epoch 41/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 0.6466 - accuracy: 0.8019 - val_loss: 1.5780 - val_accuracy: 0.4877
#
# Epoch 00041: saving model to ./tmp.h5
# Epoch 42/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 0.6282 - accuracy: 0.8095 - val_loss: 1.6113 - val_accuracy: 0.4847
#
# Epoch 00042: saving model to ./tmp.h5
# Epoch 43/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 0.6106 - accuracy: 0.8171 - val_loss: 1.5997 - val_accuracy: 0.4887
#
# Epoch 00043: saving model to ./tmp.h5
# Epoch 44/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.5916 - accuracy: 0.8233 - val_loss: 1.6128 - val_accuracy: 0.4851
#
# Epoch 00044: saving model to ./tmp.h5
# Epoch 45/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.5737 - accuracy: 0.8306 - val_loss: 1.6281 - val_accuracy: 0.4862
#
# Epoch 00045: saving model to ./tmp.h5
# Epoch 46/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.5561 - accuracy: 0.8379 - val_loss: 1.6472 - val_accuracy: 0.4821
#
# Epoch 00046: saving model to ./tmp.h5
# Epoch 47/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.5408 - accuracy: 0.8444 - val_loss: 1.6641 - val_accuracy: 0.4810
#
# Epoch 00047: saving model to ./tmp.h5
# Epoch 48/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.5227 - accuracy: 0.8510 - val_loss: 1.6808 - val_accuracy: 0.4830
#
# Epoch 00048: saving model to ./tmp.h5
# Epoch 49/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.5080 - accuracy: 0.8571 - val_loss: 1.7085 - val_accuracy: 0.4779
#
# Epoch 00049: saving model to ./tmp.h5
# Epoch 50/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.4912 - accuracy: 0.8627 - val_loss: 1.7155 - val_accuracy: 0.4856
#
# Epoch 00050: saving model to ./tmp.h5
# 10000/10000 [==============================] - 1s 65us/step

# %%
plt.plot(range(len(train_loss)), train_loss, label="train loss")
plt.plot(range(len(valid_loss)), valid_loss, label="valid loss")
plt.hlines(y=loss_loadback, xmin=0, xmax=len(train_loss), colors='r', linestyles='--')
plt.legend()
plt.title("Loss")
plt.show()

plt.plot(range(len(train_acc)), train_acc, label="train accuracy")
plt.plot(range(len(valid_acc)), valid_acc, label="valid accuracy")
plt.hlines(y=acc_loadback, xmin=0, xmax=len(train_loss), colors='r', linestyles='--')
plt.legend()
plt.title("Accuracy")
plt.show()

# %% [markdown]
# ## save_best_only=True

# %%
model_ckpt = ModelCheckpoint(filepath="./tmp.h5", 
                             monitor="val_loss",
                             verbose=1,
                             save_best_only=True)

# %%
model = build_mlp(input_shape=x_train.shape[1:])
model.summary()
optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

model.fit(x_train, y_train, 
          epochs=EPOCHS, 
          batch_size=BATCH_SIZE, 
          validation_data=(x_test, y_test), 
          shuffle=True,
          callbacks=[model_ckpt]
         )

# Collect results
train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]
train_acc = model.history.history["accuracy"]
valid_acc = model.history.history["val_accuracy"]

# Load back
model = keras.models.load_model("./tmp.h5")
loss_loadback, acc_loadback = model.evaluate(x_test, y_test)
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 2s 40us/step - loss: 2.1681 - accuracy: 0.2711 - val_loss: 2.0831 - val_accuracy: 0.2264
#
# Epoch 00001: val_loss improved from inf to 2.08305, saving model to ./tmp.h5
# Epoch 2/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 1.7389 - accuracy: 0.3904 - val_loss: 1.9195 - val_accuracy: 0.3382
#
# Epoch 00002: val_loss improved from 2.08305 to 1.91950, saving model to ./tmp.h5
# Epoch 3/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 1.6161 - accuracy: 0.4344 - val_loss: 1.8055 - val_accuracy: 0.3746
#
# Epoch 00003: val_loss improved from 1.91950 to 1.80549, saving model to ./tmp.h5
# Epoch 4/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 1.5463 - accuracy: 0.4590 - val_loss: 1.7206 - val_accuracy: 0.4051
#
# Epoch 00004: val_loss improved from 1.80549 to 1.72064, saving model to ./tmp.h5
# Epoch 5/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 1.4921 - accuracy: 0.4768 - val_loss: 1.6354 - val_accuracy: 0.4278
#
# Epoch 00005: val_loss improved from 1.72064 to 1.63536, saving model to ./tmp.h5
# Epoch 6/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 1.4476 - accuracy: 0.4943 - val_loss: 1.5885 - val_accuracy: 0.4434
#
# Epoch 00006: val_loss improved from 1.63536 to 1.58852, saving model to ./tmp.h5
# Epoch 7/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 1.4087 - accuracy: 0.5065 - val_loss: 1.5576 - val_accuracy: 0.4522
#
# Epoch 00007: val_loss improved from 1.58852 to 1.55759, saving model to ./tmp.h5
# Epoch 8/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 1.3739 - accuracy: 0.5213 - val_loss: 1.5400 - val_accuracy: 0.4571
#
# Epoch 00008: val_loss improved from 1.55759 to 1.54003, saving model to ./tmp.h5
# Epoch 9/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 1.3422 - accuracy: 0.5319 - val_loss: 1.5019 - val_accuracy: 0.4727
#
# Epoch 00009: val_loss improved from 1.54003 to 1.50191, saving model to ./tmp.h5
# Epoch 10/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 1.3122 - accuracy: 0.5414 - val_loss: 1.4894 - val_accuracy: 0.4752
#
# Epoch 00010: val_loss improved from 1.50191 to 1.48942, saving model to ./tmp.h5
# Epoch 11/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 1.2843 - accuracy: 0.5549 - val_loss: 1.4944 - val_accuracy: 0.4747
#
# Epoch 00011: val_loss did not improve from 1.48942
# Epoch 12/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 1.2581 - accuracy: 0.5623 - val_loss: 1.4723 - val_accuracy: 0.4872
#
# Epoch 00012: val_loss improved from 1.48942 to 1.47233, saving model to ./tmp.h5
# Epoch 13/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 1.2317 - accuracy: 0.5736 - val_loss: 1.4637 - val_accuracy: 0.4873
#
# Epoch 00013: val_loss improved from 1.47233 to 1.46371, saving model to ./tmp.h5
# Epoch 14/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 1.2065 - accuracy: 0.5844 - val_loss: 1.4786 - val_accuracy: 0.4803
#
# Epoch 00014: val_loss did not improve from 1.46371
# Epoch 15/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 1.1838 - accuracy: 0.5925 - val_loss: 1.4546 - val_accuracy: 0.4905
#
# Epoch 00015: val_loss improved from 1.46371 to 1.45465, saving model to ./tmp.h5
# Epoch 16/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 1.1594 - accuracy: 0.6005 - val_loss: 1.4548 - val_accuracy: 0.4917
#
# Epoch 00016: val_loss did not improve from 1.45465
# Epoch 17/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 1.1370 - accuracy: 0.6105 - val_loss: 1.4683 - val_accuracy: 0.4849
#
# Epoch 00017: val_loss did not improve from 1.45465
# Epoch 18/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 1.1151 - accuracy: 0.6180 - val_loss: 1.4545 - val_accuracy: 0.4936
#
# Epoch 00018: val_loss improved from 1.45465 to 1.45446, saving model to ./tmp.h5
# Epoch 19/50
# 50000/50000 [==============================] - 2s 30us/step - loss: 1.0924 - accuracy: 0.6278 - val_loss: 1.4467 - val_accuracy: 0.4936
#
# Epoch 00019: val_loss improved from 1.45446 to 1.44673, saving model to ./tmp.h5
# Epoch 20/50
# 50000/50000 [==============================] - 2s 30us/step - loss: 1.0694 - accuracy: 0.6365 - val_loss: 1.4537 - val_accuracy: 0.4927
#
# Epoch 00020: val_loss did not improve from 1.44673
# Epoch 21/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 1.0483 - accuracy: 0.6435 - val_loss: 1.4528 - val_accuracy: 0.4939
#
# Epoch 00021: val_loss did not improve from 1.44673
# Epoch 22/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 1.0281 - accuracy: 0.6530 - val_loss: 1.4444 - val_accuracy: 0.4996
#
# Epoch 00022: val_loss improved from 1.44673 to 1.44442, saving model to ./tmp.h5
# Epoch 23/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 1.0067 - accuracy: 0.6586 - val_loss: 1.4523 - val_accuracy: 0.4971
#
# Epoch 00023: val_loss did not improve from 1.44442
# Epoch 24/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.9857 - accuracy: 0.6672 - val_loss: 1.4445 - val_accuracy: 0.4998
#
# Epoch 00024: val_loss did not improve from 1.44442
# Epoch 25/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.9652 - accuracy: 0.6751 - val_loss: 1.4618 - val_accuracy: 0.4944
#
# Epoch 00025: val_loss did not improve from 1.44442
# Epoch 26/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.9452 - accuracy: 0.6839 - val_loss: 1.4641 - val_accuracy: 0.4923
#
# Epoch 00026: val_loss did not improve from 1.44442
# Epoch 27/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.9250 - accuracy: 0.6917 - val_loss: 1.4757 - val_accuracy: 0.4936
#
# Epoch 00027: val_loss did not improve from 1.44442
# Epoch 28/50
# 50000/50000 [==============================] - 1s 30us/step - loss: 0.9036 - accuracy: 0.6987 - val_loss: 1.4617 - val_accuracy: 0.4953
#
# Epoch 00028: val_loss did not improve from 1.44442
# Epoch 29/50
# 50000/50000 [==============================] - 1s 30us/step - loss: 0.8825 - accuracy: 0.7084 - val_loss: 1.4734 - val_accuracy: 0.4982
#
# Epoch 00029: val_loss did not improve from 1.44442
# Epoch 30/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.8608 - accuracy: 0.7170 - val_loss: 1.4610 - val_accuracy: 0.5001
#
# Epoch 00030: val_loss did not improve from 1.44442
# Epoch 31/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.8443 - accuracy: 0.7229 - val_loss: 1.4873 - val_accuracy: 0.4972
#
# Epoch 00031: val_loss did not improve from 1.44442
# Epoch 32/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.8236 - accuracy: 0.7318 - val_loss: 1.4746 - val_accuracy: 0.4997
#
# Epoch 00032: val_loss did not improve from 1.44442
# Epoch 33/50
# 50000/50000 [==============================] - 1s 30us/step - loss: 0.8037 - accuracy: 0.7377 - val_loss: 1.4708 - val_accuracy: 0.5044
#
# Epoch 00033: val_loss did not improve from 1.44442
# Epoch 34/50
# 50000/50000 [==============================] - 1s 30us/step - loss: 0.7841 - accuracy: 0.7485 - val_loss: 1.4984 - val_accuracy: 0.4988
#
# Epoch 00034: val_loss did not improve from 1.44442
# Epoch 35/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.7658 - accuracy: 0.7531 - val_loss: 1.4972 - val_accuracy: 0.4971
#
# Epoch 00035: val_loss did not improve from 1.44442
# Epoch 36/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.7447 - accuracy: 0.7630 - val_loss: 1.4949 - val_accuracy: 0.5082
#
# Epoch 00036: val_loss did not improve from 1.44442
# Epoch 37/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.7252 - accuracy: 0.7706 - val_loss: 1.5160 - val_accuracy: 0.4968
#
# Epoch 00037: val_loss did not improve from 1.44442
# Epoch 38/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.7070 - accuracy: 0.7778 - val_loss: 1.5228 - val_accuracy: 0.4995
#
# Epoch 00038: val_loss did not improve from 1.44442
# Epoch 39/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.6892 - accuracy: 0.7839 - val_loss: 1.5273 - val_accuracy: 0.4991
#
# Epoch 00039: val_loss did not improve from 1.44442
# Epoch 40/50
# 50000/50000 [==============================] - 1s 30us/step - loss: 0.6713 - accuracy: 0.7917 - val_loss: 1.5420 - val_accuracy: 0.4949
#
# Epoch 00040: val_loss did not improve from 1.44442
# Epoch 41/50
# 50000/50000 [==============================] - 1s 30us/step - loss: 0.6502 - accuracy: 0.8012 - val_loss: 1.5616 - val_accuracy: 0.4936
#
# Epoch 00041: val_loss did not improve from 1.44442
# Epoch 42/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.6343 - accuracy: 0.8051 - val_loss: 1.5482 - val_accuracy: 0.5054
#
# Epoch 00042: val_loss did not improve from 1.44442
# Epoch 43/50
# 50000/50000 [==============================] - 1s 30us/step - loss: 0.6131 - accuracy: 0.8129 - val_loss: 1.5690 - val_accuracy: 0.4968
#
# Epoch 00043: val_loss did not improve from 1.44442
# Epoch 44/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.5982 - accuracy: 0.8199 - val_loss: 1.5916 - val_accuracy: 0.4900
#
# Epoch 00044: val_loss did not improve from 1.44442
# Epoch 45/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.5813 - accuracy: 0.8257 - val_loss: 1.5986 - val_accuracy: 0.4993
#
# Epoch 00045: val_loss did not improve from 1.44442
# Epoch 46/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.5636 - accuracy: 0.8347 - val_loss: 1.6037 - val_accuracy: 0.4980
#
# Epoch 00046: val_loss did not improve from 1.44442
# Epoch 47/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.5447 - accuracy: 0.8407 - val_loss: 1.6379 - val_accuracy: 0.4894
#
# Epoch 00047: val_loss did not improve from 1.44442
# Epoch 48/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.5303 - accuracy: 0.8468 - val_loss: 1.6220 - val_accuracy: 0.4967
#
# Epoch 00048: val_loss did not improve from 1.44442
# Epoch 49/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.5113 - accuracy: 0.8550 - val_loss: 1.6481 - val_accuracy: 0.4937
#
# Epoch 00049: val_loss did not improve from 1.44442
# Epoch 50/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 0.4966 - accuracy: 0.8594 - val_loss: 1.6519 - val_accuracy: 0.4942
#
# Epoch 00050: val_loss did not improve from 1.44442
# 10000/10000 [==============================] - 1s 60us/step

# %%
plt.plot(range(len(train_loss)), train_loss, label="train loss")
plt.plot(range(len(valid_loss)), valid_loss, label="valid loss")
plt.hlines(y=loss_loadback, xmin=0, xmax=len(train_loss), colors='r', linestyles='--')
plt.legend()
plt.title("Loss")
plt.show()

plt.plot(range(len(train_acc)), train_acc, label="train accuracy")
plt.plot(range(len(valid_acc)), valid_acc, label="valid accuracy")
plt.hlines(y=acc_loadback, xmin=0, xmax=len(train_loss), colors='r', linestyles='--')
plt.legend()
plt.title("Accuracy")
plt.show()

# %% [markdown]
# ## After reset

# %%
model = keras.models.load_model("./tmp.h5")
loss_loadback, acc_loadback = model.evaluate(x_test, y_test)
# Out:
# 10000/10000 [==============================] - 1s 82us/step

# %%
loss_loadback
# Out:
# 1.4444193078994751

# %%
acc_loadback
# Out:
# 0.49959999322891235

# %%
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________

# %%
optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

model.fit(x_train, y_train, 
          epochs=EPOCHS, 
          batch_size=BATCH_SIZE, 
          validation_data=(x_test, y_test), 
          shuffle=True,
         )

# Collect results
train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]
train_acc = model.history.history["accuracy"]
valid_acc = model.history.history["val_accuracy"]
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 2s 37us/step - loss: 1.0078 - accuracy: 0.6600 - val_loss: 1.4517 - val_accuracy: 0.5020
# Epoch 2/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.9902 - accuracy: 0.6655 - val_loss: 1.4452 - val_accuracy: 0.4980
# Epoch 3/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.9721 - accuracy: 0.6714 - val_loss: 1.4585 - val_accuracy: 0.4956
# Epoch 4/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.9508 - accuracy: 0.6816 - val_loss: 1.4528 - val_accuracy: 0.4987
# Epoch 5/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.9302 - accuracy: 0.6897 - val_loss: 1.4566 - val_accuracy: 0.4952
# Epoch 6/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.9078 - accuracy: 0.6989 - val_loss: 1.4622 - val_accuracy: 0.4994
# Epoch 7/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.8908 - accuracy: 0.7055 - val_loss: 1.4664 - val_accuracy: 0.4946
# Epoch 8/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.8705 - accuracy: 0.7131 - val_loss: 1.4658 - val_accuracy: 0.5020
# Epoch 9/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.8486 - accuracy: 0.7221 - val_loss: 1.4744 - val_accuracy: 0.4997
# Epoch 10/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.8289 - accuracy: 0.7301 - val_loss: 1.4960 - val_accuracy: 0.4977
# Epoch 11/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.8087 - accuracy: 0.7365 - val_loss: 1.4844 - val_accuracy: 0.4986
# Epoch 12/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.7895 - accuracy: 0.7438 - val_loss: 1.4809 - val_accuracy: 0.5026
# Epoch 13/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.7700 - accuracy: 0.7523 - val_loss: 1.4946 - val_accuracy: 0.4979
# Epoch 14/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.7527 - accuracy: 0.7589 - val_loss: 1.5230 - val_accuracy: 0.4973
# Epoch 15/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.7328 - accuracy: 0.7665 - val_loss: 1.5103 - val_accuracy: 0.4957
# Epoch 16/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.7139 - accuracy: 0.7741 - val_loss: 1.5150 - val_accuracy: 0.5015
# Epoch 17/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.6950 - accuracy: 0.7816 - val_loss: 1.5429 - val_accuracy: 0.4959
# Epoch 18/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.6772 - accuracy: 0.7887 - val_loss: 1.5376 - val_accuracy: 0.5004
# Epoch 19/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.6585 - accuracy: 0.7960 - val_loss: 1.5416 - val_accuracy: 0.4989
# Epoch 20/50
# 50000/50000 [==============================] - 1s 30us/step - loss: 0.6398 - accuracy: 0.8032 - val_loss: 1.5565 - val_accuracy: 0.4948
# Epoch 21/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.6205 - accuracy: 0.8123 - val_loss: 1.5722 - val_accuracy: 0.4977
# Epoch 22/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.6006 - accuracy: 0.8193 - val_loss: 1.5719 - val_accuracy: 0.5008
# Epoch 23/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.5842 - accuracy: 0.8253 - val_loss: 1.5836 - val_accuracy: 0.4973
# Epoch 24/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.5687 - accuracy: 0.8299 - val_loss: 1.5937 - val_accuracy: 0.4970
# Epoch 25/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.5512 - accuracy: 0.8384 - val_loss: 1.6184 - val_accuracy: 0.4979
# Epoch 26/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.5346 - accuracy: 0.8447 - val_loss: 1.6183 - val_accuracy: 0.4936
# Epoch 27/50
# 50000/50000 [==============================] - 1s 30us/step - loss: 0.5191 - accuracy: 0.8504 - val_loss: 1.6395 - val_accuracy: 0.4940
# Epoch 28/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.4997 - accuracy: 0.8583 - val_loss: 1.6706 - val_accuracy: 0.4934
# Epoch 29/50
# 50000/50000 [==============================] - 1s 30us/step - loss: 0.4854 - accuracy: 0.8644 - val_loss: 1.6832 - val_accuracy: 0.4908
# Epoch 30/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.4679 - accuracy: 0.8716 - val_loss: 1.6810 - val_accuracy: 0.4945
# Epoch 31/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.4519 - accuracy: 0.8774 - val_loss: 1.6799 - val_accuracy: 0.4941
# Epoch 32/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.4365 - accuracy: 0.8836 - val_loss: 1.7114 - val_accuracy: 0.4898
# Epoch 33/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.4241 - accuracy: 0.8878 - val_loss: 1.7300 - val_accuracy: 0.4954
# Epoch 34/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.4087 - accuracy: 0.8954 - val_loss: 1.7358 - val_accuracy: 0.4965
# Epoch 35/50
# 50000/50000 [==============================] - 2s 30us/step - loss: 0.3945 - accuracy: 0.9004 - val_loss: 1.7571 - val_accuracy: 0.4890
# Epoch 36/50
# 50000/50000 [==============================] - 2s 31us/step - loss: 0.3783 - accuracy: 0.9070 - val_loss: 1.7764 - val_accuracy: 0.4877
# Epoch 37/50
# 50000/50000 [==============================] - 1s 30us/step - loss: 0.3625 - accuracy: 0.9114 - val_loss: 1.7682 - val_accuracy: 0.4875
# Epoch 38/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.3498 - accuracy: 0.9173 - val_loss: 1.7954 - val_accuracy: 0.4877
# Epoch 39/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.3373 - accuracy: 0.9205 - val_loss: 1.8342 - val_accuracy: 0.4866
# Epoch 40/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.3241 - accuracy: 0.9262 - val_loss: 1.8248 - val_accuracy: 0.4819
# Epoch 41/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.3119 - accuracy: 0.9319 - val_loss: 1.8617 - val_accuracy: 0.4886
# Epoch 42/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.2999 - accuracy: 0.9355 - val_loss: 1.8862 - val_accuracy: 0.4867
# Epoch 43/50
# 50000/50000 [==============================] - 2s 31us/step - loss: 0.2863 - accuracy: 0.9406 - val_loss: 1.9147 - val_accuracy: 0.4798
# Epoch 44/50
# 50000/50000 [==============================] - 1s 30us/step - loss: 0.2762 - accuracy: 0.9442 - val_loss: 1.8847 - val_accuracy: 0.4893
# Epoch 45/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.2665 - accuracy: 0.9464 - val_loss: 1.9041 - val_accuracy: 0.4873
# Epoch 46/50
# 50000/50000 [==============================] - 1s 30us/step - loss: 0.2547 - accuracy: 0.9502 - val_loss: 1.9366 - val_accuracy: 0.4810
# Epoch 47/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.2446 - accuracy: 0.9534 - val_loss: 1.9472 - val_accuracy: 0.4817
# Epoch 48/50
# 50000/50000 [==============================] - 1s 30us/step - loss: 0.2325 - accuracy: 0.9583 - val_loss: 1.9695 - val_accuracy: 0.4799
# Epoch 49/50
# 50000/50000 [==============================] - 1s 30us/step - loss: 0.2244 - accuracy: 0.9604 - val_loss: 1.9605 - val_accuracy: 0.4832
# Epoch 50/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.2157 - accuracy: 0.9625 - val_loss: 2.0026 - val_accuracy: 0.4836

# %%
plt.plot(range(len(train_loss)), train_loss, label="train loss")
plt.plot(range(len(valid_loss)), valid_loss, label="valid loss")
plt.hlines(y=loss_loadback, xmin=0, xmax=len(train_loss), colors='r', linestyles='--')
plt.legend()
plt.title("Loss")
plt.show()

plt.plot(range(len(train_acc)), train_acc, label="train accuracy")
plt.plot(range(len(valid_acc)), valid_acc, label="valid accuracy")
plt.hlines(y=acc_loadback, xmin=0, xmax=len(train_loss), colors='r', linestyles='--')
plt.legend()
plt.title("Accuracy")
plt.show()
