# %% [markdown]
# ## 範例重點
# * 學習如何在 keras 中加入 model checkpoint
# * 知道如何設定監控目標
# * 比較使用最佳與非最佳參數時的 performance

# %%
import os
import keras

# 本範例不需使用 GPU, 將 GPU 設定為 "無"
os.environ["CUDA_VISIBLE_DEVICES"] = ""
# Out:
# Using TensorFlow backend.

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# 資料前處理 - X 標準化
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# 資料前處理 -Y 轉成 onehot
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
from keras.layers import BatchNormalization

"""
建立神經網路，並加入 BN layer
"""
def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128]):
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(input_layer)
            x = BatchNormalization()(x)
        else:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(x)
            x = BatchNormalization()(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
## 超參數設定
LEARNING_RATE = 1e-3
EPOCHS = 50
BATCH_SIZE = 1024
MOMENTUM = 0.95

# %%
"""
# 載入 Callbacks, 並將監控目標設為 validation loss, 且只存最佳參數時的模型
"""
from keras.callbacks import ModelCheckpoint

model_ckpt = ModelCheckpoint(filepath="./tmp.h5", 
                             monitor="val_loss",
                             verbose=1,
                             save_best_only=True)

# %%
model = build_mlp(input_shape=x_train.shape[1:])
model.summary()
optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

model.fit(x_train, y_train, 
          epochs=EPOCHS, 
          batch_size=BATCH_SIZE, 
          validation_data=(x_test, y_test), 
          shuffle=True,
          callbacks=[model_ckpt]
         )

# Collect results
train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]
train_acc = model.history.history["accuracy"]
valid_acc = model.history.history["val_accuracy"]

# Load back
model = keras.models.load_model("./tmp.h5")
loss_loadback, acc_loadback = model.evaluate(x_test, y_test)
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 2s 40us/step - loss: 2.2070 - accuracy: 0.2671 - val_loss: 2.0877 - val_accuracy: 0.2416
#
# Epoch 00001: val_loss improved from inf to 2.08768, saving model to ./tmp.h5
# Epoch 2/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 1.7535 - accuracy: 0.3863 - val_loss: 1.9622 - val_accuracy: 0.3086
#
# Epoch 00002: val_loss improved from 2.08768 to 1.96225, saving model to ./tmp.h5
# Epoch 3/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 1.6230 - accuracy: 0.4317 - val_loss: 1.8200 - val_accuracy: 0.3682
#
# Epoch 00003: val_loss improved from 1.96225 to 1.82003, saving model to ./tmp.h5
# Epoch 4/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 1.5462 - accuracy: 0.4572 - val_loss: 1.7167 - val_accuracy: 0.4001
#
# Epoch 00004: val_loss improved from 1.82003 to 1.71669, saving model to ./tmp.h5
# Epoch 5/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 1.4911 - accuracy: 0.4803 - val_loss: 1.6428 - val_accuracy: 0.4253
#
# Epoch 00005: val_loss improved from 1.71669 to 1.64278, saving model to ./tmp.h5
# Epoch 6/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 1.4452 - accuracy: 0.4958 - val_loss: 1.6256 - val_accuracy: 0.4221
#
# Epoch 00006: val_loss improved from 1.64278 to 1.62564, saving model to ./tmp.h5
# Epoch 7/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 1.4051 - accuracy: 0.5104 - val_loss: 1.5541 - val_accuracy: 0.4517
#
# Epoch 00007: val_loss improved from 1.62564 to 1.55408, saving model to ./tmp.h5
# Epoch 8/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 1.3696 - accuracy: 0.5222 - val_loss: 1.5248 - val_accuracy: 0.4586
#
# Epoch 00008: val_loss improved from 1.55408 to 1.52482, saving model to ./tmp.h5
# Epoch 9/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 1.3358 - accuracy: 0.5364 - val_loss: 1.5113 - val_accuracy: 0.4649
#
# Epoch 00009: val_loss improved from 1.52482 to 1.51125, saving model to ./tmp.h5
# Epoch 10/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 1.3053 - accuracy: 0.5470 - val_loss: 1.4996 - val_accuracy: 0.4688
#
# Epoch 00010: val_loss improved from 1.51125 to 1.49959, saving model to ./tmp.h5
# Epoch 11/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 1.2779 - accuracy: 0.5588 - val_loss: 1.4900 - val_accuracy: 0.4764
#
# Epoch 00011: val_loss improved from 1.49959 to 1.49004, saving model to ./tmp.h5
# Epoch 12/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 1.2518 - accuracy: 0.5660 - val_loss: 1.4932 - val_accuracy: 0.4772
#
# Epoch 00012: val_loss did not improve from 1.49004
# Epoch 13/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 1.2258 - accuracy: 0.5773 - val_loss: 1.4838 - val_accuracy: 0.4766
#
# Epoch 00013: val_loss improved from 1.49004 to 1.48381, saving model to ./tmp.h5
# Epoch 14/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 1.1998 - accuracy: 0.5853 - val_loss: 1.4720 - val_accuracy: 0.4814
#
# Epoch 00014: val_loss improved from 1.48381 to 1.47199, saving model to ./tmp.h5
# Epoch 15/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 1.1763 - accuracy: 0.5947 - val_loss: 1.4671 - val_accuracy: 0.4877
#
# Epoch 00015: val_loss improved from 1.47199 to 1.46709, saving model to ./tmp.h5
# Epoch 16/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 1.1517 - accuracy: 0.6042 - val_loss: 1.4725 - val_accuracy: 0.4835
#
# Epoch 00016: val_loss did not improve from 1.46709
# Epoch 17/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 1.1285 - accuracy: 0.6138 - val_loss: 1.4876 - val_accuracy: 0.4828
#
# Epoch 00017: val_loss did not improve from 1.46709
# Epoch 18/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 1.1071 - accuracy: 0.6214 - val_loss: 1.4717 - val_accuracy: 0.4872
#
# Epoch 00018: val_loss did not improve from 1.46709
# Epoch 19/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 1.0842 - accuracy: 0.6294 - val_loss: 1.4663 - val_accuracy: 0.4879
#
# Epoch 00019: val_loss improved from 1.46709 to 1.46634, saving model to ./tmp.h5
# Epoch 20/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 1.0619 - accuracy: 0.6370 - val_loss: 1.4866 - val_accuracy: 0.4862
#
# Epoch 00020: val_loss did not improve from 1.46634
# Epoch 21/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 1.0408 - accuracy: 0.6445 - val_loss: 1.4729 - val_accuracy: 0.4887
#
# Epoch 00021: val_loss did not improve from 1.46634
# Epoch 22/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 1.0191 - accuracy: 0.6555 - val_loss: 1.4831 - val_accuracy: 0.4853
#
# Epoch 00022: val_loss did not improve from 1.46634
# Epoch 23/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.9958 - accuracy: 0.6648 - val_loss: 1.4835 - val_accuracy: 0.4919
#
# Epoch 00023: val_loss did not improve from 1.46634
# Epoch 24/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.9777 - accuracy: 0.6706 - val_loss: 1.4819 - val_accuracy: 0.4896
#
# Epoch 00024: val_loss did not improve from 1.46634
# Epoch 25/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.9545 - accuracy: 0.6795 - val_loss: 1.4800 - val_accuracy: 0.4918
#
# Epoch 00025: val_loss did not improve from 1.46634
# Epoch 26/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.9336 - accuracy: 0.6887 - val_loss: 1.4939 - val_accuracy: 0.4873
#
# Epoch 00026: val_loss did not improve from 1.46634
# Epoch 27/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 0.9132 - accuracy: 0.6966 - val_loss: 1.5005 - val_accuracy: 0.4890
#
# Epoch 00027: val_loss did not improve from 1.46634
# Epoch 28/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 0.8928 - accuracy: 0.7039 - val_loss: 1.5024 - val_accuracy: 0.4891
#
# Epoch 00028: val_loss did not improve from 1.46634
# Epoch 29/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.8745 - accuracy: 0.7111 - val_loss: 1.5093 - val_accuracy: 0.4892
#
# Epoch 00029: val_loss did not improve from 1.46634
# Epoch 30/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 0.8533 - accuracy: 0.7198 - val_loss: 1.5055 - val_accuracy: 0.4914
#
# Epoch 00030: val_loss did not improve from 1.46634
# Epoch 31/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.8334 - accuracy: 0.7278 - val_loss: 1.5113 - val_accuracy: 0.4917
#
# Epoch 00031: val_loss did not improve from 1.46634
# Epoch 32/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 0.8143 - accuracy: 0.7348 - val_loss: 1.5065 - val_accuracy: 0.4927
#
# Epoch 00032: val_loss did not improve from 1.46634
# Epoch 33/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 0.7927 - accuracy: 0.7447 - val_loss: 1.5271 - val_accuracy: 0.4941
#
# Epoch 00033: val_loss did not improve from 1.46634
# Epoch 34/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 0.7762 - accuracy: 0.7502 - val_loss: 1.5299 - val_accuracy: 0.4906
#
# Epoch 00034: val_loss did not improve from 1.46634
# Epoch 35/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 0.7543 - accuracy: 0.7599 - val_loss: 1.5355 - val_accuracy: 0.4923
#
# Epoch 00035: val_loss did not improve from 1.46634
# Epoch 36/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 0.7364 - accuracy: 0.7667 - val_loss: 1.5425 - val_accuracy: 0.4947
#
# Epoch 00036: val_loss did not improve from 1.46634
# Epoch 37/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 0.7156 - accuracy: 0.7761 - val_loss: 1.5443 - val_accuracy: 0.4939
#
# Epoch 00037: val_loss did not improve from 1.46634
# Epoch 38/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 0.6970 - accuracy: 0.7823 - val_loss: 1.5630 - val_accuracy: 0.4861
#
# Epoch 00038: val_loss did not improve from 1.46634
# Epoch 39/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 0.6796 - accuracy: 0.7894 - val_loss: 1.5938 - val_accuracy: 0.4830
#
# Epoch 00039: val_loss did not improve from 1.46634
# Epoch 40/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 0.6614 - accuracy: 0.7971 - val_loss: 1.5746 - val_accuracy: 0.4871
#
# Epoch 00040: val_loss did not improve from 1.46634
# Epoch 41/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 0.6419 - accuracy: 0.8029 - val_loss: 1.5992 - val_accuracy: 0.4875
#
# Epoch 00041: val_loss did not improve from 1.46634
# Epoch 42/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 0.6250 - accuracy: 0.8113 - val_loss: 1.5931 - val_accuracy: 0.4914
#
# Epoch 00042: val_loss did not improve from 1.46634
# Epoch 43/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 0.6069 - accuracy: 0.8185 - val_loss: 1.6102 - val_accuracy: 0.4883
#
# Epoch 00043: val_loss did not improve from 1.46634
# Epoch 44/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 0.5908 - accuracy: 0.8240 - val_loss: 1.6366 - val_accuracy: 0.4849
#
# Epoch 00044: val_loss did not improve from 1.46634
# Epoch 45/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 0.5711 - accuracy: 0.8314 - val_loss: 1.6322 - val_accuracy: 0.4848
#
# Epoch 00045: val_loss did not improve from 1.46634
# Epoch 46/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 0.5525 - accuracy: 0.8405 - val_loss: 1.6479 - val_accuracy: 0.4851
#
# Epoch 00046: val_loss did not improve from 1.46634
# Epoch 47/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 0.5380 - accuracy: 0.8455 - val_loss: 1.6605 - val_accuracy: 0.4884
#
# Epoch 00047: val_loss did not improve from 1.46634
# Epoch 48/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.5223 - accuracy: 0.8525 - val_loss: 1.6819 - val_accuracy: 0.4877
#
# Epoch 00048: val_loss did not improve from 1.46634
# Epoch 49/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.5046 - accuracy: 0.8599 - val_loss: 1.6942 - val_accuracy: 0.4875
#
# Epoch 00049: val_loss did not improve from 1.46634
# Epoch 50/50
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.4910 - accuracy: 0.8629 - val_loss: 1.7022 - val_accuracy: 0.4827
#
# Epoch 00050: val_loss did not improve from 1.46634
# 10000/10000 [==============================] - 1s 61us/step

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(range(len(train_loss)), train_loss, label="train loss")
plt.plot(range(len(valid_loss)), valid_loss, label="valid loss")
plt.hlines(y=loss_loadback, xmin=0, xmax=len(train_loss), colors='r', linestyles='--')
plt.legend()
plt.title("Loss")
plt.show()

plt.plot(range(len(train_acc)), train_acc, label="train accuracy")
plt.plot(range(len(valid_acc)), valid_acc, label="valid accuracy")
plt.hlines(y=acc_loadback, xmin=0, xmax=len(train_loss), colors='r', linestyles='--')
plt.legend()
plt.title("Accuracy")
plt.show()

# %% [markdown]
# ## Work
# 1. 試比較 save_best_only 與否的差異
# 2. 請僅存入將 save_weights_only 設定為 True, 並嘗試 reset ipynb 並將模型與權重重新建回並預測 x_test
